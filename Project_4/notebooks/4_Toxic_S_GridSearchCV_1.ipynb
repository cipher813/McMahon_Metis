# %% [markdown]
# ## Toxic: GridSearchCV (Supervised)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.base import TransformerMixin
from sklearn.utils import resample, shuffle
from sklearn.cross_validation import train_test_split 
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

from sklearn.metrics import (accuracy_score, classification_report,confusion_matrix, precision_score, 
                             recall_score, f1_score, roc_curve, roc_auc_score, average_precision_score, 
                             precision_recall_curve, auc)

# %%
df = pd.read_pickle('../data/toxictrain.pkl')
print(df.shape)
df.head()
# Out:
# (159571, 19)
#                                 id  \
# idx
# 3a4c7758fad18de3  3a4c7758fad18de3
# 24d2b50726b67167  24d2b50726b67167
# c586b7a2fd575b13  c586b7a2fd575b13
# 77d84b1321c22d9a  77d84b1321c22d9a
# 1368c10281978876  1368c10281978876
#
#                                                        comment_text  toxic  \
# idx
# 3a4c7758fad18de3  , I hope your retarded kids get anal raped and...      1
# 24d2b50726b67167  I am going to murder ZimZalaBim ST47 for being...      1
# c586b7a2fd575b13  Shut up you asswipe, we don't care. I'll decap...      1
# 77d84b1321c22d9a  LGBT \n\nyou little fuck , are you a fag , tha...      1
# 1368c10281978876  You're a stupid cunt \n\nFuck you dumb arse, y...      1
#
#                   severe_toxic  obscene  threat  insult  identity_hate  \
# idx
# 3a4c7758fad18de3             1        1       1       1              1
# 24d2b50726b67167             1        1       1       1              1
# c586b7a2fd575b13             1        1       1       1              1
# 77d84b1321c22d9a             1        1       1       1              1
# 1368c10281978876             1        1       1       1              1
#
#                       category  rating  \
# idx
# 3a4c7758fad18de3  ToSTObThInIH       6
# 24d2b50726b67167  ToSTObThInIH       6
# c586b7a2fd575b13  ToSTObThInIH       6
# 77d84b1321c22d9a  ToSTObThInIH       6
# 1368c10281978876  ToSTObThInIH       6
#
#                                                      comment_text_s  \
# idx
# 3a4c7758fad18de3  , I hope your retarded kids get anal raped and...
# 24d2b50726b67167  I am going to murder ZimZalaBim ST47 for being...
# c586b7a2fd575b13  Shut up you asswipe, we don't care. I'll decap...
# 77d84b1321c22d9a  LGBT \n\nyou little fuck , are you a fag , tha...
# 1368c10281978876  You're a stupid cunt \n\nFuck you dumb arse, y...
#
#                                                      comment_text_f  \
# idx
# 3a4c7758fad18de3  , hope retarded kids get anal raped murdered h...
# 24d2b50726b67167  am going to murder ZimZalaBim ST47 being evil ...
# c586b7a2fd575b13  Shut up asswipe , do n't care . 'll decapitate...
# 77d84b1321c22d9a  LGBT little fuck , are fag , piece shit page i...
# 1368c10281978876  're stupid cunt Fuck dumb arse , mum has hairy...
#
#                                                         token_clean  \
# idx
# 3a4c7758fad18de3  [i, hope, your, retarded, kids, get, anal, rap...
# 24d2b50726b67167  [i, am, going, to, murder, zimzalabim, st47, f...
# c586b7a2fd575b13  [shut, up, you, asswipe, we, dont, care, ill, ...
# 77d84b1321c22d9a  [lgbt, you, little, fuck, are, you, a, fag, th...
# 1368c10281978876  [youre, a, stupid, cunt, fuck, you, dumb, arse...
#
#                                                          sent_token  \
# idx
# 3a4c7758fad18de3  [, I hope your retarded kids get anal raped an...
# 24d2b50726b67167  [I am going to murder ZimZalaBim ST47 for bein...
# c586b7a2fd575b13  [Shut up you asswipe, we don't care., I'll dec...
# 77d84b1321c22d9a  [LGBT \n\nyou little fuck , are you a fag , th...
# 1368c10281978876  [You're a stupid cunt \n\nFuck you dumb arse, ...
#
#                   polarity_comment  polarity_comment_s  word_count  \
# idx
# 3a4c7758fad18de3              0.00                0.00          94
# 24d2b50726b67167              0.00                0.00          12
# c586b7a2fd575b13             -0.25               -0.25          24
# 77d84b1321c22d9a              0.00                0.00          56
# 1368c10281978876              0.00                0.00          59
#
#                   char_count  char_count_s
# idx
# 3a4c7758fad18de3         494           494
# 24d2b50726b67167          68            68
# c586b7a2fd575b13        3890          1000
# 77d84b1321c22d9a         280           280
# 1368c10281978876         278           278

# %%
class DenseTransformer(TransformerMixin):

    def transform(self, X, y=None, **fit_params):
        return X.todense()

    def fit_transform(self, X, y=None, **fit_params):
        self.fit(X, y, **fit_params)
        return self.transform(X)

    def fit(self, X, y=None, **fit_params):
        return self

# %%
# Upsampling
df_majority = df[df.rating == 0]
df_minority = df[df.rating > 0]
print(df_majority.shape, df_minority.shape)

df_minority_upsampled = resample(df_minority, replace=True, n_samples=127000)

df = pd.concat([df_majority,df_minority_upsampled])
print(df.shape)
# Out:
# (143346, 19) (16225, 19)
# (270346, 19)

# %%
df_1 = shuffle(df)[-5000:]
# X = df_1['comment_text_s']
# y = df_1['toxic']
# print(X.shape, y.shape)

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

# k_range = list(range(1, 101))
# print(X_train.shape, y_train.shape)
# print(X_test.shape,y_test.shape)

# %%
X = df_1['comment_text_s']
y = df_1['toxic']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

model = RandomForestClassifier()
param_grid = [{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
pipe = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('to_dense', DenseTransformer()),
                     ('grid', grid)])
pipe.fit(X_train,y_train) 
grid_predictions = pipe.predict(X_test)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.1s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.1s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.1s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  16.0s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.3s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.9s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.9s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.9s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.5s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  21.2s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.7min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.5s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.0s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.7s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.0s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.7min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.5min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.4s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.5s
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.7min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total= 1.0min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total= 1.2min
# [CV] .............. max_features=log2, n_estimators=500, total= 1.2min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.9min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.9min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.9min
# [CV] ............. max_features=log2, n_estimators=1000, total= 2.1min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.5min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.4min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.5min finished
# {'max_features': 'auto', 'n_estimators': 1000} RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) [[755  73]
#  [205 467]]              precision    recall  f1-score   support
#
#           0       0.79      0.91      0.84       828
#           1       0.86      0.69      0.77       672
#
# avg / total       0.82      0.81      0.81      1500

# %%
categories = ['toxic', 'severe_toxic', 'obscene', 'threat','insult', 'identity_hate']
gs_cat = {}

for cat in categories:
    X = df_1['comment_text_s']
    y = df_1[cat]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

    model = RandomForestClassifier()
    param_grid = [{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]
    grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
    pipe = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('to_dense', DenseTransformer()),
                         ('grid', grid)])
    pipe.fit(X_train,y_train) 
    grid_predictions = pipe.predict(X_test)
    best_params = grid.best_params_
    best_estimator = grid.best_estimator_
    best_cm = confusion_matrix(y_test,grid_predictions)
    best_cr = classification_report(y_test,grid_predictions)
    gs_cat[cat] = best_params, best_estimator, best_cm, best_cr
gs_cat
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.1s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.2s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  16.5s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  17.1s
# [CV] .............. max_features=auto, n_estimators=100, total=  17.6s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.9s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.0s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.7s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  21.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  21.0s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  20.7s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.7min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.7min
# [CV] .............. max_features=auto, n_estimators=500, total= 1.7min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.7min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.7min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.7s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.8s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.6s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.7min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.3min
# [CV] .............. max_features=log2, n_estimators=100, total=  10.7s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.5min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.6s
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.3min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  47.7s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  48.8s
# [CV] .............. max_features=log2, n_estimators=500, total=  47.8s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.0min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.3min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.3min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.4min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 2.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.0min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  5.6min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.4s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  19.5s
# [CV] .............. max_features=auto, n_estimators=100, total=  19.5s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  20.7s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.3s
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.8s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.3s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  24.3s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.3s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.7s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.0s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.0s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.2s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   9.4s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   9.3s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.7min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   9.5s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.7min
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.9min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  40.5s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  44.2s
# [CV] .............. max_features=log2, n_estimators=500, total=  42.8s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.3min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.3min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.3min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.6min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 2.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.0min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  5.9min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.4s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.2s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.5s
# [CV] .............. max_features=auto, n_estimators=100, total=  19.7s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  23.4s
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.3s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.0s
# [CV] .............. max_features=sqrt, n_estimators=100, total=  25.3s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  24.3s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.8s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.8s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.8s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.0s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.7min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.6s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.0min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.6s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.0min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.0min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  52.3s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  50.3s
# [CV] .............. max_features=log2, n_estimators=500, total=  49.6s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.3min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.1min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.1min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.1min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.2min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   0.8s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   0.8s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   0.8s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=   8.7s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=   9.8s
# [CV] .............. max_features=auto, n_estimators=100, total=  10.6s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.2s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.4s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  15.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  14.6s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  14.6s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.0min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.1min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.2min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.1min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.1min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.5s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.6s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.4s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 2.1min
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.2min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   6.9s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   6.2s
# [CV] ............. max_features=auto, n_estimators=1000, total= 2.3min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   7.0s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 2.3min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  34.2s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  34.0s
# [CV] .............. max_features=log2, n_estimators=500, total=  32.7s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 2.0min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 2.1min
# [CV] ............. max_features=log2, n_estimators=1000, total=  51.0s
# [CV] ............. max_features=log2, n_estimators=1000, total=  55.0s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 1.9min
# [CV] ............. max_features=log2, n_estimators=1000, total=  39.2s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  3.8min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.2s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.4s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  20.2s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  22.2s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.2s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.3s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  25.3s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  24.5s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.7s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.7s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.9s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.9min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.9min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.4s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.0min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  50.3s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  51.9s
# [CV] .............. max_features=log2, n_estimators=500, total=  51.3s
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.4min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.5min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.5min
# [CV] ............. max_features=log2, n_estimators=1000, total=  54.6s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.2min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.3min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.6s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.6s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.7s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  23.0s
# [CV] .............. max_features=auto, n_estimators=100, total=  22.7s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  25.3s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.2s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.4s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  26.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  26.9s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  28.5s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.2min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.2min
# [CV] .............. max_features=auto, n_estimators=500, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.3min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.3min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.7s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.8s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.6s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   9.3s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=   9.6s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.3min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  10.2s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.6min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.6min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.4min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  48.1s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  46.1s
# [CV] .............. max_features=log2, n_estimators=500, total=  45.8s
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.2min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.3min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.0min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.2min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.0min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.4min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  7.0min finished
# {'identity_hate': ({'max_features': 'auto', 'n_estimators': 500},
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#               max_depth=None, max_features='auto', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#               oob_score=False, random_state=None, verbose=0,
#               warm_start=False),
#   array([[1421,   12],
#          [  56,   11]]),
#   '             precision    recall  f1-score   support\n\n          0       0.96      0.99      0.98      1433\n          1       0.48      0.16      0.24        67\n\navg / total       0.94      0.95      0.94      1500\n'),
#  'insult': ({'max_features': 'sqrt', 'n_estimators': 1000},
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#               max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#               oob_score=False, random_state=None, verbose=0,
#               warm_start=False),
#   array([[1141,   17],
#          [ 196,  146]]),
#   '             precision    recall  f1-score   support\n\n          0       0.85      0.99      0.91      1158\n          1       0.90      0.43      0.58       342\n\navg / total       0.86      0.86      0.84      1500\n'),
#  'obscene': ({'max_features': 'auto', 'n_estimators': 1000},
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#               max_depth=None, max_features='auto', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#               oob_score=False, random_state=None, verbose=0,
#               warm_start=False),
#   array([[1121,   13],
#          [ 154,  212]]),
#   '             precision    recall  f1-score   support\n\n          0       0.88      0.99      0.93      1134\n          1       0.94      0.58      0.72       366\n\navg / total       0.89      0.89      0.88      1500\n'),
#  'severe_toxic': ({'max_features': 'sqrt', 'n_estimators': 1000},
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#               max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#               oob_score=False, random_state=None, verbose=0,
#               warm_start=False),
#   array([[1423,    1],
#          [  68,    8]]),
#   '             precision    recall  f1-score   support\n\n          0       0.95      1.00      0.98      1424\n          1       0.89      0.11      0.19        76\n\navg / total       0.95      0.95      0.94      1500\n'),
#  'threat': ({'max_features': 'sqrt', 'n_estimators': 1000},
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#               max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#               oob_score=False, random_state=None, verbose=0,
#               warm_start=False),
#   array([[1476,    1],
#          [  20,    3]]),
#   '             precision    recall  f1-score   support\n\n          0       0.99      1.00      0.99      1477\n          1       0.75      0.13      0.22        23\n\navg / total       0.98      0.99      0.98      1500\n'),
#  'toxic': ({'max_features': 'sqrt', 'n_estimators': 1000},
#   RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#               max_depth=None, max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#               oob_score=False, random_state=None, verbose=0,
#               warm_start=False),
#   array([[755,  81],
#          [176, 488]]),
#   '             precision    recall  f1-score   support\n\n          0       0.81      0.90      0.85       836\n          1       0.86      0.73      0.79       664\n\navg / total       0.83      0.83      0.83      1500\n')}
