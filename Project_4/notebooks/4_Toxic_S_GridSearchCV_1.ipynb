# %% [markdown]
# ## Toxic: GridSearchCV (Supervised)

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.base import TransformerMixin
from sklearn.utils import resample, shuffle
from sklearn.cross_validation import train_test_split 
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

from sklearn.metrics import (accuracy_score, classification_report,confusion_matrix, precision_score, 
                             recall_score, f1_score, roc_curve, roc_auc_score, average_precision_score, 
                             precision_recall_curve, auc)

from xgboost import XGBClassifier
# Out:
# /home/cipher000/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Assumptions

# %%
df = pd.read_pickle('../data/toxictrain.pkl')
print(df.shape)
# df.head()

categories = ['clean','toxic', 'severe_toxic', 'obscene', 'threat','insult', 'identity_hate']
models = [['rfc',RandomForestClassifier(),[{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]],
          ['xgbc',XGBClassifier(),[{'n_estimators':[50,100,150,200],'max_depth':[2,3,4,5,6,7,8,9],'min_child_weight':[2,3,4,5],
               'colsample_bytree':[0.2,0.6,0.8],'colsample_bylevel':[0.2,0.6,0.8]}]],
          ['gbc',GradientBoostingClassifier(),[{'n_estimators': [10, 100, 500, 1000]}]]]
# Out:
# (159571, 24)

# %% [markdown]
# ### Helper Functions

# %%
class DenseTransformer(TransformerMixin):

    def transform(self, X, y=None, **fit_params):
        return X.todense()

    def fit_transform(self, X, y=None, **fit_params):
        self.fit(X, y, **fit_params)
        return self.transform(X)

    def fit(self, X, y=None, **fit_params):
        return self

# %% [markdown]
# ### Upsampling

# %%
# Upsampling
df_Cl = df[df.rating == 0]
df_To = df[df.toxic == 1]
df_ST = df[df.severe_toxic == 1]
df_Ob = df[df.obscene == 1]
df_Th = df[df.threat == 1]
df_In = df[df.insult == 1]
df_IH = df[df.identity_hate == 1]
print(df_Cl.shape, df_To.shape,df_ST.shape,df_Ob.shape,df_Th.shape,df_In.shape,df_IH.shape)

df_STu = resample(df_ST, replace=True, n_samples=20000)
df_Obu = resample(df_Ob, replace=True, n_samples=20000)
df_Thu = resample(df_Th, replace=True, n_samples=30000)
df_Inu = resample(df_In, replace=True, n_samples=20000)
df_IHu = resample(df_IH, replace=True, n_samples=30000)
print(df_STu.shape,df_Obu.shape,df_Thu.shape,df_Inu.shape,df_IHu.shape)


df = pd.concat([df_Cl, df_STu, df_Obu, df_Thu, df_Inu, df_IHu])

print(df.shape)
# Out:
# (143346, 24) (15294, 24) (1595, 24) (8449, 24) (478, 24) (7877, 24) (1405, 24)
# (20000, 24) (20000, 24) (30000, 24) (20000, 24) (30000, 24)
# (263346, 24)

# %%
df_1 = shuffle(df)[-5000:]

# %%
def gridsearch_models(data, models, categories):
    model_dict = {}
    for model in models:
        print(model)
        model_name = model[0]
        model_model = model[1]
        param_grid = model[2]
        for item in categories:    
            X = data['comment_text_s']
            y = data[item]
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

            grid = GridSearchCV(model_model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
            pipe = Pipeline([('vect', CountVectorizer()),
                                 ('tfidf', TfidfTransformer()),
                                 ('to_dense', DenseTransformer()),
                                 ('grid', grid)])
            pipe.fit(X_train,y_train) 
            grid_predictions = pipe.predict(X_test)
            best_params = grid.best_params_
            best_estimator = grid.best_estimator_
            best_cm = confusion_matrix(y_test,grid_predictions)
            best_cr = classification_report(y_test,grid_predictions)
            model_dict[(model_name,item)] = {"best_params":best_params, "best_estimator":best_estimator, "best_cm":best_cm, "best_cr":best_cr}        
    return model_dict

# %%
gm = gridsearch_models(df_1, models, categories)
# Out:
# ['rfc', RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False), [{'max_features': ['auto', 'sqrt', 'log2'], 'n_estimators': [10, 100, 500, 1000]}]]
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.2s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  19.2s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  20.4s
# [CV] .............. max_features=auto, n_estimators=100, total=  19.6s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.1s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   4.1s
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.6s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  25.4s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.2s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.0s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.6s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.3s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] .............. max_features=log2, n_estimators=100, total=  12.3s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.8s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.4s
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  53.1s
# [CV] .............. max_features=log2, n_estimators=500, total=  55.7s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  54.5s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.4min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.4min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.5min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 2.9min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.1min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.1min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.2s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.2s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.7s
# [CV] .............. max_features=auto, n_estimators=100, total=  18.8s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  20.3s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.9s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.8s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.5s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  22.8s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.1s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.1s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.6s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.8min
# [CV] .............. max_features=log2, n_estimators=100, total=  12.4s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.6min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.6s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  55.7s
# [CV] .............. max_features=log2, n_estimators=500, total=  55.0s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  53.6s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.4min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.4min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.0min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.1min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.1min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.4s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.6s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.6s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  21.0s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  23.5s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.0s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  28.9s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.9s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  26.6s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  26.7s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  25.6s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.2min
# [CV] .............. max_features=auto, n_estimators=500, total= 2.2min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.2min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.1min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.2min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.8s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  13.4s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.2min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.2min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.1s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.2min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.6s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.4min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  58.0s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  57.1s
# [CV] .............. max_features=log2, n_estimators=500, total=  57.5s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.0min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.0min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.2min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.6min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  7.0min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.4s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.4s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.6s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  22.2s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  24.0s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.0s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.4s
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  25.1s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.9s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.0min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.2s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.5s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  13.2s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.9min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.8s
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.9min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.3s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.9min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  59.4s
# [CV] .............. max_features=log2, n_estimators=500, total=  55.8s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  58.0s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.6min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.1min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.1min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.5min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.5s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.8s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.9s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  24.6s
# [CV] .............. max_features=auto, n_estimators=100, total=  24.1s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  28.1s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.4s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   4.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   5.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  29.4s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  31.2s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  30.0s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.5min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.6min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.7min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.5min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.5min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.2s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.8s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.8s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.5min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.1s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 5.2min
# [CV] ............. max_features=auto, n_estimators=1000, total= 5.1min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 5.0min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  56.4s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  56.5s
# [CV] .............. max_features=log2, n_estimators=500, total=  55.9s
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.7min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.5min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.7min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.3min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.0min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  7.9min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.1s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.4s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  17.9s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  19.6s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  22.4s
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.4s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.6s
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.9s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.0s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.3s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  23.2s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.4s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.2s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.0s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.8s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.7min
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 1.9min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.4s
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.8min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.3s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 3.8min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  54.2s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  54.3s
# [CV] .............. max_features=log2, n_estimators=500, total=  54.3s
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.4min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.7min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.1min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.1min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  6.2min finished
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.5s
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.7s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   1.6s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  25.1s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=100, total=  26.4s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] .............. max_features=auto, n_estimators=100, total=  28.6s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   4.3s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   3.6s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   4.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  30.6s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  29.7s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  33.1s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.4min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.5min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 2.5min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.4min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.4min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.3s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   1.9s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.0s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  11.5s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  12.7s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.8min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.5min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 5.0min
# [CV] .............. max_features=log2, n_estimators=100, total=  11.3s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.9min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  57.6s
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total=  59.9s
# [CV] .............. max_features=log2, n_estimators=500, total=  59.9s
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.7min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.6min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.5min
# [CV] ............. max_features=log2, n_estimators=1000, total= 1.3min
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 3.9min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  7.7min finished
# ['xgbc', XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1), [{'max_depth': [2, 3, 4, 5, 6, 7, 8, 9], 'min_child_weight': [2, 3, 4, 5], 'colsample_bylevel': [0.2, 0.6, 0.8], 'n_estimators': [50, 100, 150, 200], 'colsample_bytree': [0.2, 0.6, 0.8]}]]
# Fitting 3 folds for each of 1152 candidates, totalling 3456 fits
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.1min
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.1min
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.2min
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.1min
# [CV] max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.1min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.6min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.3min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.6min
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.5min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.1min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.7min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.2min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.7min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.2min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.8min
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.1min
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.4min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=2, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.2min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.2min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.2min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.2min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.2min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.5min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.4min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.2min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 10.0min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.0min
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.3min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.6min
# [CV] max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.6min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=3, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.7min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.1min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.4min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.5min
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.6min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2, total= 1.2min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.6min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 4.4min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.9min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.7min
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 5.2min
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV] max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=4, colsample_bylevel=0.2, n_estimators=200, colsample_bytree=0.2, total= 5.2min
# [CV] max_depth=3, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=100, colsample_bytree=0.2, total= 2.9min
# [CV] max_depth=3, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# [CV]  max_depth=2, min_child_weight=5, colsample_bylevel=0.2, n_estimators=150, colsample_bytree=0.2, total= 3.8min
# [CV] max_depth=3, min_child_weight=2, colsample_bylevel=0.2, n_estimators=50, colsample_bytree=0.2
# ...
# [CV] max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 5.2min
# [CV] max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.3min
# [CV] max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.3min
# [CV] max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.6min
# [CV] max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.6min
# [CV] max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.7min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.3min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 1.8min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 1.9min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 4.9min
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 5.1min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 1.8min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 5.1min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.4min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.4min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.8min
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.4min
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV] max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.7min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.7min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.3min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.3min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 5.2min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 5.2min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 5.1min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.2min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.7min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.7min
# [CV]  max_depth=4, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 6.7min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.2min
# [CV] max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.0min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.4min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.2min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 3.9min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.1min
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.1min
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV] max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=2, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 7.8min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.2min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.2min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.4min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.3min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.4min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.1min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.4min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.1min
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.3min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.4min
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.2min
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV] max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=3, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.4min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.4min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.1min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.2min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.1min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.2min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.1min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.1min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.0min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.1min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.0min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.1min
# [CV] max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=4, colsample_bylevel=0.8, n_estimators=200, colsample_bytree=0.8, total= 8.1min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8, total= 4.3min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.2min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8
# [CV]  max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.8min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.8min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.3min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=100, colsample_bytree=0.8
# [CV]  max_depth=5, min_child_weight=5, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8, total= 6.2min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8
# [CV]  max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=50, colsample_bytree=0.8, total= 2.7min
# [CV] max_depth=6, min_child_weight=2, colsample_bylevel=0.8, n_estimators=150, colsample_bytree=0.8

# %%
# def gridsearch_model_classes(data, model, categories,param_grid):
#     model_dict = {}
#     for item in categories:    
#         X = data['comment_text_s']
#         y = data[item]
#         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

#         model = model
#         param_grid = param_grid
#         grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
#         pipe = Pipeline([('vect', CountVectorizer()),
#                              ('tfidf', TfidfTransformer()),
#                              ('to_dense', DenseTransformer()),
#                              ('grid', grid)])
#         pipe.fit(X_train,y_train) 
#         grid_predictions = pipe.predict(X_test)
#         best_params = grid.best_params_
#         best_estimator = grid.best_estimator_
#         best_cm = confusion_matrix(y_test,grid_predictions)
#         best_cr = classification_report(y_test,grid_predictions)
#         model_dict[item] = {"best_params":best_params, "best_estimator":best_estimator, 
#                             "best_cm":best_cm, "best_cr":best_cr}
#     return model_dict

# %%
# model = RandomForestClassifier()
# param_grid = [{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]
# gridsearch_model_classes(df_1, model,categories, param_grid)

# %%
# model = XGBClassifier()
# param_grid = [{'n_estimators':[50,100,150,200],'max_depth':[2,3,4,5,6,7,8,9],'min_child_weight':[2,3,4,5],
#                'colsample_bytree':[0.2,0.6,0.8],'colsample_bylevel':[0.2,0.6,0.8]}]
# gridsearch_model_classes(df_1, model,categories, param_grid)

# %%
# model = GradientBoostingClassifier()
# param_grid = [{'n_estimators': [10, 100, 500, 1000]}]
# gridsearch_model_classes(df_1, model,categories, param_grid)

# %%
X = df_1['comment_text_s']
y = df_1['toxic']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

model = RandomForestClassifier()
param_grid = [{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
pipe = Pipeline([('vect', CountVectorizer()),
                     ('tfidf', TfidfTransformer()),
                     ('to_dense', DenseTransformer()),
                     ('grid', grid)])
pipe.fit(X_train,y_train) 
grid_predictions = pipe.predict(X_test)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)

# %%
categories = ['clean','toxic', 'severe_toxic', 'obscene', 'threat','insult', 'identity_hate']
gs_cat = {}

for cat in categories:
    X = df_1['comment_text_s']
    y = df_1[cat]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

    model = RandomForestClassifier()
    param_grid = [{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]
    grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
    pipe = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('to_dense', DenseTransformer()),
                         ('grid', grid)])
    pipe.fit(X_train,y_train) 
    grid_predictions = pipe.predict(X_test)
    best_params = grid.best_params_
    best_estimator = grid.best_estimator_
    best_cm = confusion_matrix(y_test,grid_predictions)
    best_cr = classification_report(y_test,grid_predictions)
    gs_cat[cat] = best_params, best_estimator, best_cm, best_cr
gs_cat
