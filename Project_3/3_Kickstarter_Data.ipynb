# %% [markdown]
# # Project 3: Predicting the Success of a Kickstarter Campaign
# A supervised learning exercise featuring logistic regression, SVM, KNN, and [Others?]

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from flask_sqlalchemy import SQLAlchemy
import os

# %%
import sys
sys.executable
# Out:
# '/Users/brianmcmahon/anaconda3/envs/tensorflow1.4/bin/python'

# %%
# env variable at tensorflow1.4 per https://conda.io/docs/user-guide/tasks/manage-environments.html#saving-environment-variables
# and https://vsupalov.com/flask-sqlalchemy-postgres/

def get_env_variable(name):
    try:
        return os.environ[name]
    except KeyError:
        message = "Expected environment variable '{}' not set.".format(name)
        raise Exception(message)

# the values of those depend on your setup
POSTGRES_URL = get_env_variable("POSTGRES_URL")
POSTGRES_USER = get_env_variable("POSTGRES_USER")
POSTGRES_PW = get_env_variable("POSTGRES_PW")
POSTGRES_DB = get_env_variable("POSTGRES_DB")

# %%
DB_URL = 'postgresql+psycopg2://{user}:{pw}@{url}/{db}'.format(user=POSTGRES_USER,pw=POSTGRES_PW,url=POSTGRES_URL,db=POSTGRES_DB)

# app.config['SQLALCHEMY_DATABASE_URI'] = DB_URL
# app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False # silence the deprecation warning

# db = SQLAlchemy(app)

# %%
engine_var = DB_URL
engine = create_engine(engine_var)

# %%
# pd.read_sql_query('''SELECT * FROM allstarfull LIMIT 5''',engine)

# %%
df = pd.read_csv('data/ks-projects-201801.csv') # From kaggle dataset at https://www.kaggle.com/kemical/kickstarter-projects
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
df['deadline'] = pd.to_datetime(df['deadline'])
df['launched'] = pd.to_datetime(df['launched']) 
df['launched'] = df['launched'].apply(lambda x: x.strftime('%Y-%m-%d'))
df['launched'] = pd.to_datetime(df['launched']) 
df = df.sort_values(['deadline'], ascending=[False])
df['campaign_length'] = df['deadline'] - df['launched']
df['pct_goal_achieved'] = (df['usd_pledged_real'] / df['usd_goal_real'])*100
df = df.set_index('ID')
print(df.shape)
df.head()
# Out:
# (378661, 16)
#                                   name category main_category currency  \
# ID
# 22387366                  Nerd Collect     Apps    Technology      GBP
# 1036415983               Aikyam : Onnu    Music         Music      USD
# 1916988520   Back in Black Hills Movie    Drama  Film & Video      USD
# 1365286494         From the Wilderness    Drama  Film & Video      USD
# 55596200    Plateforme de statistiques     Apps    Technology      EUR
#
#              deadline      goal   launched  pledged state  backers country  \
# ID
# 22387366   2018-03-03  150000.0 2018-01-02      0.0  live        0      GB
# 1036415983 2018-03-03   10000.0 2018-01-02    174.0  live        3      US
# 1916988520 2018-03-03    5500.0 2018-01-02      0.0  live        0      US
# 1365286494 2018-03-02    2500.0 2018-01-01    482.0  live       19      US
# 55596200   2018-03-02    9000.0 2018-01-01      0.0  live        0      FR
#
#             usd pledged  usd_pledged_real  usd_goal_real campaign_length  \
# ID
# 22387366            0.0               0.0      204596.60         60 days
# 1036415983        174.0             174.0       10000.00         60 days
# 1916988520          0.0               0.0        5500.00         60 days
# 1365286494          0.0             482.0        2500.00         60 days
# 55596200            0.0               0.0       10923.26         60 days
#
#             pct_goal_achieved
# ID
# 22387366                 0.00
# 1036415983               1.74
# 1916988520               0.00
# 1365286494              19.28
# 55596200                 0.00

# %%
# remove canceled, undefined, live and suspended
df = df[(df['state'] == 'successful') | (df['state'] == 'failed')]
df = pd.DataFrame(df)
start_date = pd.to_datetime('2017-06-30') 
df = df[df['launched'] >= start_date] # filter from start date to current
print(df.shape)
df.tail()
# Out:
# (19291, 16)
#                                                          name  \
# ID
# 315499236   Help struggling brooklyn fashion designer with...
# 2003107805                            Die Cut Python Stickers
# 999667180                        VARIANT WARS - The Prisoners
# 1145118881                                  Softball Ring Box
# 1261713735                           101 Piano Songs. 1 Album
#
#                    category main_category currency   deadline    goal  \
# ID
# 315499236           Apparel       Fashion      USD 2017-07-07  3500.0
# 2003107805     Illustration           Art      USD 2017-07-07   200.0
# 999667180           Fiction    Publishing      USD 2017-07-07   325.0
# 1145118881            Games         Games      USD 2017-07-07   150.0
# 1261713735  Classical Music         Music      USD 2017-07-05  1000.0
#
#              launched  pledged       state  backers country  usd pledged  \
# ID
# 315499236  2017-06-30      0.0      failed        0      US          0.0
# 2003107805 2017-06-30    158.0      failed       30      US          0.0
# 999667180  2017-06-30    425.0  successful        7      US        425.0
# 1145118881 2017-07-02     65.0      failed        1      US         65.0
# 1261713735 2017-07-02     33.0      failed        3      US         32.0
#
#             usd_pledged_real  usd_goal_real campaign_length  pct_goal_achieved
# ID
# 315499236                0.0         3500.0          7 days           0.000000
# 2003107805             158.0          200.0          7 days          79.000000
# 999667180              425.0          325.0          7 days         130.769231
# 1145118881              65.0          150.0          5 days          43.333333
# 1261713735              33.0         1000.0          3 days           3.300000

# %%
df.main_category = pd.Categorical(df.main_category) 
df['main_category_code'] = df.main_category.cat.codes

df.country = pd.Categorical(df.country) 
df['country_code'] = df.country.cat.codes

df.currency = pd.Categorical(df.currency) 
df['currency_code'] = df.currency.cat.codes

df.state = pd.Categorical(df.state) 
df['state_code'] = df.state.cat.codes

df.head(100)
# Out:
#                                                          name  \
# ID
# 1031685482  You Sparkle Inside: A Kids' Book + Commissions...
# 1176736360                        THE NEW BILLY WYLDER RECORD
# 1894703097           Driftwood Holly ***The Venice Project***
# 311863059                             On a Limb's debut album
# 2076121120                             Briggs Barbecue Sauces
# 1938619867                               Pizza Britt T-shirts
# 1058353500                     Nightbloom Gardens - Deathwish
# 1117804738                               THE NEW MEYTAL ALBUM
# 704593914   PAPIROARMABLES VOLUME 1 by Chakz Armada ( a pa...
# 712996656                                       Singing Pipes
# 251949329                                  Cozy Coozie Sleeve
# 1481417993  SAVE THE SONG FAIRIES!! The Andy Davis 52 Week...
# 715585534                                               TOTEM
# 1959919280         Leo & Helen: The Lost City of the Americas
# 793399813   The Smittle House: Bed and Breakfast and Fine ...
# 1155319275      Lund Saddlery Hybrid Tack Trunks/Tack Lockers
# 496222489                                          ildze.shop
# 1941144366                   Taking sports to the next height
# 940741116             Lauren Morgan | New England Weatherwear
# 1676840321                              #BalancedLivingTVShow
# 1674608170 2017-11-20      10.00      failed        1      US         0.00
# 1464700230 2017-12-01   26815.00  successful      177      US      3334.00
# 1194173741 2017-12-02     117.00      failed        2      US         0.00
# 1964506089 2017-11-10       0.00      failed        0      GB         0.00
# 1524989211 2017-12-02      15.00      failed        1      US        15.00
#
#             usd_pledged_real  usd_goal_real campaign_length  \
# ID
# 1031685482           6083.00        2000.00         27 days
# 1176736360          11169.56       10000.00         33 days
# 1894703097          30615.02       30112.50         35 days
# 311863059            1743.00        1000.00         24 days
# 2076121120              1.00      200000.00         60 days
# 1938619867             54.00         380.00         50 days
# 1058353500              0.00        5420.64         25 days
# 1117804738         156961.09       80000.00         46 days
# 704593914             219.45        1549.03         45 days
# 712996656               0.00       10000.00         40 days
# 251949329            1039.00         800.00         27 days
# 1481417993           8638.00          52.00         29 days
# 715585534               1.00       35000.00         41 days
# 1959919280           3151.00       25000.00         23 days
# 793399813            1578.00       12000.00         41 days
# 1155319275           3840.93        2797.76         27 days
# 496222489               0.00        2168.10         40 days
# 1941144366              0.00       30000.00         30 days
# 940741116           13602.00       10000.00         42 days
# 1676840321             83.93       19984.01         60 days
# 1544576485           6360.00        5000.00         40 days
# 2038706738            250.00         200.00         42 days
# 1550599281             80.00       20300.00         36 days
# 277992527           12489.65       12251.00         32 days
# 1097309900           6612.00        4500.00         60 days
# 1125429077             55.00        1500.00         30 days
# 1386143513            299.00        4000.00         30 days
# 46484651             1555.00        1500.00         20 days
# 2018467410              0.00        2000.00         21 days
# 1518351367          10083.88       10000.00         58 days
# ...                      ...            ...             ...
# 1110190997              0.00       15000.00         30 days
# 1502905086           7323.29        4065.48         36 days
# 614161278              10.00       75000.00         39 days
# 1384049706              5.00        2997.00         30 days
# 647974699               0.00       15987.21         29 days
# 101640075               1.00        4000.00         30 days
# 923704935           10640.10         741.86         31 days
# 1385430491          13408.00       12000.00         28 days
# 1359157243            470.00        3000.00         19 days
# 526756548             662.67        4065.48         30 days
# 1773435651            310.00        3000.00         31 days
# 1531662033          73217.00       60000.00         38 days
# 1232162171            525.00         500.00         26 days
# 1772115678            402.00        5000.00         35 days
# 569712580               0.00         464.71         35 days
# 683922916              50.00      150000.00         40 days
# 1131972424             85.00       20000.00         30 days
# 1973809216           4144.76        4065.48         30 days
# 1161255150              0.00       18067.50         45 days
# 691051751               0.00       25000.00         40 days
# 2071146296           1560.00       10000.00         48 days
# 398886530            2115.00        7500.00         19 days
# 1100181726            159.87        2398.08         13 days
# 224677231             810.00        1650.00         18 days
# 419194237               0.00        3387.90         45 days
# 1674608170             10.00      300000.00         42 days
# 1464700230          26815.00       18000.00         31 days
# 1194173741            117.00        3600.00         30 days
# 1964506089              0.00        2710.32         52 days
# 1524989211             15.00        3000.00         30 days
#
#             pct_goal_achieved  main_category_code  country_code  \
# ID
# 1031685482         304.150000                  12            21
# 1176736360         111.695600                  10            21
# 1894703097         101.668809                  10             5
# 311863059          174.300000                  10            21
# 2076121120           0.000500                   7            21
# 1938619867          14.210526                   2            21
# 224677231              13           0
# 419194237               5           0
# 1674608170             13           0
# 1464700230             13           1
# 1194173741             13           0
# 1964506089              5           0
# 1524989211             13           0
#
# [100 rows x 20 columns]

# %%
# TO DO: send to sql; retreive in "Supervised" JN
try:
    df.to_sql("kickstarter_data", engine, if_exists='replace')
except Exception as e:
    print(e)
    pass

# Temporary fix:
df.to_pickle('data/kickstarter_data.pkl')
df.to_csv('data/kickstarter_data.csv')
# Out:
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/pandas/core/generic.py:1534: UserWarning: the 'timedelta' type is not supported, and will be written as integer values (ns frequency) to the database.
#   chunksize=chunksize, dtype=dtype)

# %%
# !scp /data/kickstarter_data.csv myaws:~ | export POSTGRES_PW
# Out:
# Enter passphrase for key '/Users/brianmcmahon/.ssh/id_rsa':

# %%
# try:
#     pd.read_sql_query('''DROP TABLE kickstarter_data;''',engine)
# except Exception as e:
#     print(e)
#     pass
# try:
#     pd.read_sql_query('''COPY kickstarter_data FROM 'data/kickstarter_data.csv' DELIMITER ',' CSV HEADER;''',engine)
# except Exception as e:
#     print(e)
#     pass

# %% [markdown]
# ## State of Success

# %%
df_state = df.groupby(["state"]).count().sort_values(['name'], ascending=[False])
df_state = pd.DataFrame(df_state, columns={'name'})
print(df_state.shape)
df_state

# %%
df_state = df.groupby(["state"]).sum().sort_values(['usd pledged'], ascending=[False])
df_state = pd.DataFrame(df_state, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_state.shape)
df_state

# %%
df_country = df.groupby(["country"]).count().sort_values(['name'], ascending=[False])
df_country = pd.DataFrame(df_country, columns={'name'})
print(df_country.shape)
df_country

# %%
df_country = df.groupby(["country"]).sum().sort_values(['usd pledged'], ascending=[False])
df_country = pd.DataFrame(df_country, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_country.shape)
df_country

# %%
df_currency = df.groupby(["currency"]).count().sort_values(['name'], ascending=[False])
df_currency = pd.DataFrame(df_currency, columns={'name'})
print(df_currency.shape)
df_currency

# %%
df_currency = df.groupby(["currency"]).sum().sort_values(['usd pledged'], ascending=[False])
df_currency = pd.DataFrame(df_currency, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_currency.shape)
df_currency

# %%
df_main_category = df.groupby(["main_category"]).count().sort_values(['name'], ascending=[False])
df_main_category = pd.DataFrame(df_main_category, columns={'name'})
print(df_main_category.shape)
df_main_category

# %%
df_main_category = df.groupby(["main_category"]).sum().sort_values(['usd pledged'], ascending=[False])
df_main_category = pd.DataFrame(df_main_category, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_main_category.shape)
df_main_category

# %%
df_category = df.groupby(["category"]).count().sort_values(['name'], ascending=[False])
print(df_category.shape)
df_category

# %%
df_category = df.groupby(["category"]).sum().sort_values(['usd pledged'], ascending=[False])
df_category = pd.DataFrame(df_category, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_category.shape)
df_category
