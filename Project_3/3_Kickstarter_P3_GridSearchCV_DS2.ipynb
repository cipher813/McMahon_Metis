# %% [markdown]
# # Kickstarter: Classification
# Tests Include:
# -KNN
# -Logistic Regression
# -Decision Trees
# -Random Forest
# -SVM
# -Gradient Boosting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import sqlalchemy
from sqlalchemy import create_engine
from flask_sqlalchemy import SQLAlchemy

from sklearn import naive_bayes
from sklearn.naive_bayes import GaussianNB, BernoulliNB,MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, RandomTreesEmbedding
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, roc_auc_score
from sklearn.metrics import average_precision_score, precision_recall_curve, auc
from sklearn.learning_curve import learning_curve
from sklearn.cross_validation import train_test_split, cross_val_predict
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.preprocessing import label_binarize, scale, StandardScaler
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import make_pipeline

from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder

from xgboost import XGBClassifier

import datetime
import warnings
import os
# %matplotlib inline

warnings.filterwarnings("ignore") #, category=DeprecationWarning)

# %%
# env variable at tensorflow1.4 per https://conda.io/docs/user-guide/tasks/manage-environments.html#saving-environment-variables
# and https://vsupalov.com/flask-sqlalchemy-postgres/

def get_env_variable(name):
    try:
        return os.environ[name]
    except KeyError:
        message = "Expected environment variable '{}' not set.".format(name)
        raise Exception(message)

# the values of those depend on your setup
POSTGRES_URL = get_env_variable("POSTGRES_URL")
POSTGRES_USER = get_env_variable("POSTGRES_USER")
POSTGRES_PW = get_env_variable("POSTGRES_PW")
POSTGRES_DB = get_env_variable("POSTGRES_DB")

# %%
DB_URL = 'postgresql+psycopg2://{user}:{pw}@{url}/{db}'.format(user=POSTGRES_USER,pw=POSTGRES_PW,url=POSTGRES_URL,db=POSTGRES_DB)

# %%
engine_var = DB_URL
engine = create_engine(engine_var)

# %%
df = pd.read_pickle('data/kickstarter_data_ds2.pkl')
df['idx'] = df['id']
df = df.set_index('idx')
# df['state'] = df['state'].replace({'failed': 0, 'successful': 1})
# df = pd.read_sql_query('''SELECT * FROM kickstarter_data_ds2''',engine)
print(df.shape)
# pd.read_sql_query('''SELECT state, main_category, main_category, currency, currency, deadline, launched, usd_goal_real, usd_pledged_real FROM kickstarter_data_ds2 LIMIT 5''',engine)
df.head()
# Out:
# (163425, 18)
#                     id                                     name       state  \
# idx
# 1396766240  1396766240  Ripple Playing Cards - Printed by USPCC      failed
# 2065169465  2065169465                      Cotton-Top Pastries  successful
# 1647325451  1647325451                              Code Switch  successful
# 727157486    727157486                            Rain Dog Farm      failed
# 1756145145  1756145145                          WANGTA: a novel  successful
#
#              category_main  category_name  backers_count  pct_goal_achieved  \
# idx
# 1396766240           games  Playing Cards            131                0.3
# 2065169465            food    Small Batch             99                1.3
# 1647325451  film_and_video         Horror             34                1.5
# 727157486             food          Farms             49                0.3
# 1756145145      publishing        Fiction             13                1.0
#
#             usd_pledged      usd_goal country currency  campaign_length  \
# idx
# 1396766240  3387.000000   9999.000000      US      USD               38
# 2065169465  9858.000000   7500.000000      US      USD               30
# 1647325451  4611.000000   3000.000000      US      USD               32
# 727157486   4741.000000  18000.000000      US      USD               38
# 1756145145   427.185132    427.185132      CA      CAD               21
#
#               deadline    launched     created  staff_pick     creator_name  \
# idx
# 1396766240  2018-01-12  2017-12-05  2017-10-08           0    B.Y. Eidelman
# 2065169465  2018-01-12  2017-12-13  2017-12-12           1      Holly Weist
# 1647325451  2018-01-12  2017-12-11  2017-11-10           0      Alba Roland
# 727157486   2018-01-12  2017-12-05  2017-11-28           1  Charlie Wainger
# 1756145145  2018-01-12  2017-12-22  2017-12-18           0   D. H. de Bruin
#
#             blurb_length
# idx
# 1396766240            16
# 2065169465             5
# 1647325451            23
# 727157486              9
# 1756145145            22

# %%
start_date = datetime.datetime.strptime('2016-01-01', "%Y-%m-%d").date()

df = df[df['launched'] >= start_date] # filter from start date to current
df = df[['state','category_main','category_name','backers_count','usd_goal','country','currency','campaign_length',
        'staff_pick','blurb_length']]
df = df.dropna()
df.shape
# Out:
# (38401, 10)

# %%
df.columns
# Out:
# Index(['state', 'category_main', 'category_name', 'backers_count', 'usd_goal',
#        'country', 'currency', 'campaign_length', 'staff_pick', 'blurb_length'],
#       dtype='object')

# %%
df_dummies = pd.get_dummies(df[['state','category_main','category_name', 'country','currency']],drop_first=True)
df = df_dummies.merge(df,how='inner',left_index=True, right_index=True)
print(df.shape)
print(df.columns)
df.info()
# Out:
# (38401, 198)
# Index(['state_successful', 'category_main_comics', 'category_main_crafts',
#        'category_main_dance', 'category_main_design', 'category_main_fashion',
#        'category_main_film_and_video', 'category_main_food',
#        'category_main_games', 'category_main_journalism',
#        ...
#        'state', 'category_main', 'category_name', 'backers_count', 'usd_goal',
#        'country', 'currency', 'campaign_length', 'staff_pick', 'blurb_length'],
#       dtype='object', length=198)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38401 entries, 1396766240 to 1094069811
# Columns: 198 entries, state_successful to blurb_length
# dtypes: float64(1), int64(4), object(5), uint8(188)
# memory usage: 11.4+ MB

# %%
# removing all variables that cannot be known before a campaign is launched, such as # backers and $ pledged
X = df.drop(['state_successful','state','category_main','category_name', 'backers_count', 'country', 'currency'], 1)
y = df['state_successful']

print(X.shape)
X.columns
# X.head()
# Out:
# (38401, 191)
# Index(['category_main_comics', 'category_main_crafts', 'category_main_dance',
#        'category_main_design', 'category_main_fashion',
#        'category_main_film_and_video', 'category_main_food',
#        'category_main_games', 'category_main_journalism',
#        'category_main_music',
#        ...
#        'currency_MXN', 'currency_NOK', 'currency_NZD', 'currency_SEK',
#        'currency_SGD', 'currency_USD', 'usd_goal', 'campaign_length',
#        'staff_pick', 'blurb_length'],
#       dtype='object', length=191)

# %% [markdown]
# ## Assumptions

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42, stratify=y)

k_range = list(range(1, 101))
print(X_train.shape, y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (26880, 191) (26880,)
# (11521, 191) (11521,)

# %%
# https://elitedatascience.com/python-machine-learning-tutorial-scikit-learn
scaler = StandardScaler().fit(X_train)
X_train_s = scaler.transform(X_train)
X_test_s = scaler.transform(X_test)
# print(X_train_s.mean(axis=0))
# print(X_train_s.std(axis=0))

# X_combined_s = np.vstack((X_train_s, X_test_s))
# y_combined = np.hstack((y_train, y_test))

# %% [markdown]
# # Phase 3: GridSearchCV

# %% [markdown]
# ## GridSearchCV: Logistic Regression

# %%
model = LogisticRegression()
param_grid = [{'penalty': ['l1','l2'],'C': [0.001,0.01,0.1,1,10,100,1000]}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train_s,y_train)
grid_predictions = grid.predict(X_test_s)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# [CV] penalty=l1, C=0.001 .............................................
# [CV] penalty=l1, C=0.001 .............................................
# [CV] penalty=l1, C=0.001 .............................................
# [CV] penalty=l2, C=0.001 .............................................
# [CV] .............................. penalty=l1, C=0.001, total=   1.5s
# [CV] .............................. penalty=l1, C=0.001, total=   1.4s
# [CV] penalty=l2, C=0.001 .............................................
# [CV] .............................. penalty=l1, C=0.001, total=   1.8s
# [CV] penalty=l2, C=0.001 .............................................
# [CV] penalty=l1, C=0.01 ..............................................
# [CV] .............................. penalty=l2, C=0.001, total=   2.2s
# [CV] penalty=l1, C=0.01 ..............................................
# [CV] ............................... penalty=l1, C=0.01, total=   1.1s
# [CV] penalty=l1, C=0.01 ..............................................
# [CV] .............................. penalty=l2, C=0.001, total=   1.3s
# [CV] .............................. penalty=l2, C=0.001, total=   1.4s
# [CV] penalty=l2, C=0.01 ..............................................
# [CV] penalty=l2, C=0.01 ..............................................
# [CV] ............................... penalty=l1, C=0.01, total=   1.3s
# [CV] penalty=l2, C=0.01 ..............................................
# [CV] ............................... penalty=l1, C=0.01, total=   1.2s
# [CV] penalty=l1, C=0.1 ...............................................
# [CV] ............................... penalty=l2, C=0.01, total=   2.1s
# [CV] ............................... penalty=l2, C=0.01, total=   2.1s
# [CV] penalty=l1, C=0.1 ...............................................
# [CV] penalty=l1, C=0.1 ...............................................
# [CV] ............................... penalty=l2, C=0.01, total=   2.1s
# [CV] penalty=l2, C=0.1 ...............................................
# [CV] ................................ penalty=l1, C=0.1, total=   3.3s
# [CV] penalty=l2, C=0.1 ...............................................
# [CV] ................................ penalty=l1, C=0.1, total=   2.7s
# [CV] penalty=l2, C=0.1 ...............................................
# [CV] ................................ penalty=l1, C=0.1, total=   3.7s
# [CV] penalty=l1, C=1 .................................................
# [CV] ................................ penalty=l2, C=0.1, total=   3.5s
# [CV] penalty=l1, C=1 .................................................
# [CV] ................................ penalty=l2, C=0.1, total=   3.8s
# [CV] penalty=l1, C=1 .................................................
# [CV] ................................ penalty=l2, C=0.1, total=   4.0s
# [CV] penalty=l2, C=1 .................................................
# [CV] .................................. penalty=l2, C=1, total=  12.4s
# [CV] penalty=l2, C=1 .................................................
# [CV] .................................. penalty=l1, C=1, total=  15.6s
# [CV] penalty=l2, C=1 .................................................
# [CV] .................................. penalty=l2, C=1, total=   9.8s
# [CV] penalty=l1, C=10 ................................................
# [CV] .................................. penalty=l2, C=1, total=  11.2s
# [CV] penalty=l1, C=10 ................................................
# [CV] .................................. penalty=l1, C=1, total=  29.4s
# [CV] penalty=l1, C=10 ................................................
# [CV] .................................. penalty=l1, C=1, total=  36.9s
# [CV] penalty=l2, C=10 ................................................
# [CV] ................................. penalty=l2, C=10, total=  24.1s
# [CV] penalty=l2, C=10 ................................................
# [CV] ................................. penalty=l2, C=10, total=  10.5s
# [CV] penalty=l2, C=10 ................................................
# [CV] ................................. penalty=l2, C=10, total=  11.2s
# [CV] penalty=l1, C=100 ...............................................
# [CV] ................................. penalty=l1, C=10, total= 1.1min
# [CV] penalty=l1, C=100 ...............................................
# [CV] ................................. penalty=l1, C=10, total= 1.1min
# [CV] penalty=l1, C=100 ...............................................
# [CV] ................................. penalty=l1, C=10, total= 1.5min
# [CV] penalty=l2, C=100 ...............................................
# [CV] ................................ penalty=l1, C=100, total=  21.1s
# [CV] penalty=l2, C=100 ...............................................
# [CV] ................................ penalty=l2, C=100, total=  13.5s
# [CV] penalty=l2, C=100 ...............................................
# [CV] ................................ penalty=l2, C=100, total=  22.2s
# [CV] penalty=l1, C=1000 ..............................................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  2.4min
# [CV] ................................ penalty=l1, C=100, total=  57.6s
# [CV] penalty=l1, C=1000 ..............................................
# [CV] ................................ penalty=l2, C=100, total=  13.5s
# [CV] penalty=l1, C=1000 ..............................................
# [CV] ................................ penalty=l1, C=100, total= 1.1min
# [CV] penalty=l2, C=1000 ..............................................
# [CV] ............................... penalty=l1, C=1000, total=  22.5s
# [CV] penalty=l2, C=1000 ..............................................
# [CV] ............................... penalty=l1, C=1000, total=  18.4s
# [CV] penalty=l2, C=1000 ..............................................
# [CV] ............................... penalty=l2, C=1000, total=  15.2s
# [CV] ............................... penalty=l2, C=1000, total=  13.4s
# [CV] ............................... penalty=l2, C=1000, total=  22.4s
# [CV] ............................... penalty=l1, C=1000, total=  39.2s
# [Parallel(n_jobs=-1)]: Done  42 out of  42 | elapsed:  3.2min finished
# {'penalty': 'l1', 'C': 1000} LogisticRegression(C=1000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) [[3925 1276]
#  [1565 4755]]              precision    recall  f1-score   support
#
#           0       0.71      0.75      0.73      5201
#           1       0.79      0.75      0.77      6320
#
# avg / total       0.76      0.75      0.75     11521

# %% [markdown]
# ## GridSearchCV: Naive Bayes

# %%
model = BernoulliNB()
param_grid = [{'alpha' : [0.0, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train_s,y_train)
grid_predictions = grid.predict(X_test_s)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] alpha=0.0 .......................................................
# [CV] alpha=0.0 .......................................................
# [CV] alpha=0.0 .......................................................
# [CV] alpha=0.0001 ....................................................
# [CV] ........................................ alpha=0.0, total=   0.5s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................................ alpha=0.0, total=   0.5s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................................ alpha=0.0, total=   0.6s
# [CV] alpha=0.001 .....................................................
# [CV] ..................................... alpha=0.0001, total=   0.6s
# [CV] alpha=0.001 .....................................................
# [CV] ..................................... alpha=0.0001, total=   0.5s
# [CV] alpha=0.001 .....................................................
# [CV] ..................................... alpha=0.0001, total=   0.6s
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total=   0.6s
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total=   0.5s
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total=   0.5s
# [CV] alpha=0.1 .......................................................
# [CV] ....................................... alpha=0.01, total=   0.5s
# [CV] ....................................... alpha=0.01, total=   0.5s
# [CV] alpha=0.1 .......................................................
# [CV] alpha=0.1 .......................................................
# [CV] ....................................... alpha=0.01, total=   0.6s
# [CV] alpha=0.5 .......................................................
# [CV] ........................................ alpha=0.1, total=   0.5s
# [CV] alpha=0.5 .......................................................
# [CV] ........................................ alpha=0.1, total=   0.6s
# [CV] ........................................ alpha=0.1, total=   0.5s
# [CV] alpha=0.5 .......................................................
# [CV] ........................................ alpha=0.5, total=   0.5s
# [CV] alpha=1.0 .......................................................
# [CV] alpha=1.0 .......................................................
# [CV] ........................................ alpha=0.5, total=   0.6s
# [CV] alpha=1.0 .......................................................
# [CV] ........................................ alpha=1.0, total=   0.5s
# [CV] ........................................ alpha=0.5, total=   0.6s
# [CV] alpha=2.0 .......................................................
# [CV] alpha=2.0 .......................................................
# [CV] ........................................ alpha=1.0, total=   0.6s
# [CV] alpha=2.0 .......................................................
# [CV] ........................................ alpha=1.0, total=   0.5s
# [CV] alpha=10.0 ......................................................
# [CV] ........................................ alpha=2.0, total=   0.4s
# [CV] ........................................ alpha=2.0, total=   0.4s
# [CV] alpha=10.0 ......................................................
# [CV] alpha=10.0 ......................................................
# [CV] ........................................ alpha=2.0, total=   0.5s
# [CV] ....................................... alpha=10.0, total=   0.4s
# [CV] ....................................... alpha=10.0, total=   0.4s
# [CV] ....................................... alpha=10.0, total=   0.4s
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.4s finished
# {'alpha': 0.5} BernoulliNB(alpha=0.5, binarize=0.0, class_prior=None, fit_prior=True) [[3755 1446]
#  [1638 4682]]              precision    recall  f1-score   support
#
#           0       0.70      0.72      0.71      5201
#           1       0.76      0.74      0.75      6320
#
# avg / total       0.73      0.73      0.73     11521

# %%
model = MultinomialNB()
param_grid = [{'alpha' : [0.0, 0.0001, 0.001, 0.01, 0.1, 0.5, 1.0, 2.0, 10.0]}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train,y_train)
grid_predictions = grid.predict(X_test)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] alpha=0.0 .......................................................
# [CV] alpha=0.0 .......................................................
# [CV] alpha=0.0 .......................................................
# [CV] alpha=0.0001 ....................................................
# [CV] ........................................ alpha=0.0, total=   0.1s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................................ alpha=0.0, total=   0.2s
# [CV] alpha=0.0001 ....................................................
# [CV] ........................................ alpha=0.0, total=   0.2s
# [CV] alpha=0.001 .....................................................
# [CV] ..................................... alpha=0.0001, total=   0.2s
# [CV] alpha=0.001 .....................................................
# [CV] ..................................... alpha=0.0001, total=   0.2s
# [CV] alpha=0.001 .....................................................
# [CV] ..................................... alpha=0.0001, total=   0.2s
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total=   0.2s
# [CV] ...................................... alpha=0.001, total=   0.2s
# [CV] alpha=0.01 ......................................................
# [CV] alpha=0.01 ......................................................
# [CV] ...................................... alpha=0.001, total=   0.2s
# [CV] alpha=0.1 .......................................................
# [CV] ....................................... alpha=0.01, total=   0.2s
# [CV] alpha=0.1 .......................................................
# [CV] ....................................... alpha=0.01, total=   0.2s
# [CV] alpha=0.1 .......................................................
# [CV] ....................................... alpha=0.01, total=   0.2s
# [CV] alpha=0.5 .......................................................
# [CV] ........................................ alpha=0.1, total=   0.2s
# [CV] alpha=0.5 .......................................................
# [CV] ........................................ alpha=0.1, total=   0.2s
# [CV] alpha=0.5 .......................................................
# [CV] ........................................ alpha=0.1, total=   0.3s
# [CV] ........................................ alpha=0.5, total=   0.2s
# [CV] alpha=1.0 .......................................................
# [CV] alpha=1.0 .......................................................
# [CV] ........................................ alpha=0.5, total=   0.3s
# [CV] alpha=1.0 .......................................................
# [CV] ........................................ alpha=0.5, total=   0.3s
# [CV] alpha=2.0 .......................................................
# [CV] ........................................ alpha=1.0, total=   0.3s
# [CV] ........................................ alpha=1.0, total=   0.2s
# [CV] alpha=2.0 .......................................................
# [CV] alpha=2.0 .......................................................
# [CV] ........................................ alpha=1.0, total=   0.2s
# [CV] alpha=10.0 ......................................................
# [CV] ........................................ alpha=2.0, total=   0.2s
# [CV] alpha=10.0 ......................................................
# [CV] ........................................ alpha=2.0, total=   0.2s
# [CV] alpha=10.0 ......................................................
# [CV] ........................................ alpha=2.0, total=   0.2s
# [CV] ....................................... alpha=10.0, total=   0.2s
# [CV] ....................................... alpha=10.0, total=   0.1s
# [CV] ....................................... alpha=10.0, total=   0.2s
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    2.4s finished
# {'alpha': 0.0} MultinomialNB(alpha=0.0, class_prior=None, fit_prior=True) [[1340 3861]
#  [ 559 5761]]              precision    recall  f1-score   support
#
#           0       0.71      0.26      0.38      5201
#           1       0.60      0.91      0.72      6320
#
# avg / total       0.65      0.62      0.57     11521

# %% [markdown]
# ## GridSearchCV: Random Forest

# %%
model = RandomForestClassifier()
param_grid = [{'n_estimators': [10, 100, 500, 1000],'max_features': ['auto', 'sqrt', 'log2']}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train_s,y_train)
grid_predictions = grid.predict(X_test_s)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=10 ..............................
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   2.3s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   2.4s
# [CV] max_features=auto, n_estimators=100 .............................
# [CV] ............... max_features=auto, n_estimators=10, total=   2.4s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.3s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.2s
# [CV] max_features=auto, n_estimators=500 .............................
# [CV] .............. max_features=auto, n_estimators=100, total=  18.2s
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.7min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=auto, n_estimators=1000 ............................
# [CV] .............. max_features=auto, n_estimators=500, total= 1.8min
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.6s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.7s
# [CV] max_features=sqrt, n_estimators=10 ..............................
# [CV] ............... max_features=sqrt, n_estimators=10, total=   2.5s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  27.1s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  30.2s
# [CV] max_features=sqrt, n_estimators=100 .............................
# [CV] .............. max_features=sqrt, n_estimators=100, total=  28.6s
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.2min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.4min
# [CV] max_features=sqrt, n_estimators=500 .............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.7min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] ............. max_features=auto, n_estimators=1000, total= 4.7min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.4min
# [CV] max_features=sqrt, n_estimators=1000 ............................
# [CV] .............. max_features=sqrt, n_estimators=500, total= 2.4min
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.5s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.3s
# [CV] max_features=log2, n_estimators=10 ..............................
# [CV] ............... max_features=log2, n_estimators=10, total=   2.2s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  18.7s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  17.6s
# [CV] max_features=log2, n_estimators=100 .............................
# [CV] .............. max_features=log2, n_estimators=100, total=  18.7s
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.3min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.1min
# [CV] max_features=log2, n_estimators=500 .............................
# [CV] ............. max_features=sqrt, n_estimators=1000, total= 4.1min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total= 1.5min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total= 1.4min
# [CV] max_features=log2, n_estimators=1000 ............................
# [CV] .............. max_features=log2, n_estimators=500, total= 1.4min
# [CV] ............. max_features=log2, n_estimators=1000, total= 2.6min
# [CV] ............. max_features=log2, n_estimators=1000, total= 2.5min
# [CV] ............. max_features=log2, n_estimators=1000, total= 2.2min
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed: 15.5min finished
# {'max_features': 'auto', 'n_estimators': 1000} RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) [[3855 1346]
#  [1453 4867]]              precision    recall  f1-score   support
#
#           0       0.73      0.74      0.73      5201
#           1       0.78      0.77      0.78      6320
#
# avg / total       0.76      0.76      0.76     11521

# %% [markdown]
# ## GridSearchCV: Gradient Boost

# %%
model = GradientBoostingClassifier()
param_grid = [{'n_estimators': [10, 100, 500, 1000]}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train_s,y_train)
grid_predictions = grid.predict(X_test_s)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] n_estimators=10 .................................................
# [CV] n_estimators=10 .................................................
# [CV] n_estimators=10 .................................................
# [CV] n_estimators=100 ................................................
# [CV] .................................. n_estimators=10, total=  12.0s
# [CV] n_estimators=100 ................................................
# [CV] .................................. n_estimators=10, total=  12.1s
# [CV] n_estimators=100 ................................................
# [CV] .................................. n_estimators=10, total=  12.0s
# [CV] n_estimators=500 ................................................
# [CV] ................................. n_estimators=100, total= 1.5min
# [CV] n_estimators=500 ................................................
# [CV] ................................. n_estimators=100, total= 1.5min
# [CV] n_estimators=500 ................................................
# [CV] ................................. n_estimators=100, total= 1.5min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................. n_estimators=500, total= 6.3min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................. n_estimators=500, total= 5.9min
# [CV] n_estimators=1000 ...............................................
# [CV] ................................. n_estimators=500, total= 5.9min
# [CV] ................................ n_estimators=1000, total= 9.8min
# [CV] ................................ n_estimators=1000, total= 7.4min
# [CV] ................................ n_estimators=1000, total= 6.8min
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 14.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed: 14.3min finished
# {'n_estimators': 500} GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=500,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False) [[4065 1136]
#  [1432 4888]]              precision    recall  f1-score   support
#
#           0       0.74      0.78      0.76      5201
#           1       0.81      0.77      0.79      6320
#
# avg / total       0.78      0.78      0.78     11521

# %% [markdown]
# ## GridSearchCV: AdaBoost

# %%
model = AdaBoostClassifier(base_estimator=DecisionTreeClassifier())
param_grid = [{"base_estimator__criterion" : ["gini", "entropy"],
               "base_estimator__splitter" :   ["best", "random"],
               'n_estimators': [1, 2],
               'base_estimator__max_depth': [1, 2],
               'algorithm': ['SAMME', 'SAMME.R']}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train,y_train)
grid_predictions = grid.predict(X_test)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.2s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.2s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    3.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.2s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.3s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.3s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=gini, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=1, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV] base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1
# [CV]  base_estimator__splitter=best, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.2s
# [CV] base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=1, total=   0.3s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.4s
# [CV]  base_estimator__splitter=random, base_estimator__max_depth=2, algorithm=SAMME.R, base_estimator__criterion=entropy, n_estimators=2, total=   0.3s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    9.7s finished
# {'n_estimators': 2, 'base_estimator__splitter': 'best', 'algorithm': 'SAMME.R', 'base_estimator__criterion': 'gini', 'base_estimator__max_depth': 2} AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=2, random_state=None) [[3294 1907]
#  [1642 4678]]              precision    recall  f1-score   support
#
#           0       0.67      0.63      0.65      5201
#           1       0.71      0.74      0.72      6320
#
# avg / total       0.69      0.69      0.69     11521

# %% [markdown]
# ## GridSearchCV: KNN

# %%
# https://stackoverflow.com/questions/37678471/i-am-trying-to-implement-gridsearchcv-to-tune-the-parameters-of-k-nearest-neighb
model = KNeighborsClassifier()
param_grid = [{'n_neighbors': list(range(1,101,3))}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train_s,y_train)
grid_predictions = grid.predict(X_test_s)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 34 candidates, totalling 102 fits
# [CV] n_neighbors=1 ...................................................
# [CV] n_neighbors=1 ...................................................
# [CV] n_neighbors=1 ...................................................
# [CV] n_neighbors=4 ...................................................
# [CV] .................................... n_neighbors=1, total=  55.2s
# [CV] n_neighbors=4 ...................................................
# [CV] .................................... n_neighbors=1, total=  55.6s
# [CV] n_neighbors=4 ...................................................
# [CV] .................................... n_neighbors=1, total=  56.0s
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=4, total= 1.0min
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=4, total= 1.0min
# [CV] n_neighbors=7 ...................................................
# [CV] .................................... n_neighbors=4, total= 1.1min
# [CV] n_neighbors=10 ..................................................
# [CV] .................................... n_neighbors=7, total= 1.1min
# [CV] n_neighbors=10 ..................................................
# [CV] .................................... n_neighbors=7, total= 1.2min
# [CV] n_neighbors=10 ..................................................
# [CV] .................................... n_neighbors=7, total=  57.7s
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=10, total= 1.0min
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=10, total=  57.6s
# [CV] n_neighbors=13 ..................................................
# [CV] ................................... n_neighbors=10, total=  57.0s
# [CV] n_neighbors=16 ..................................................
# [CV] ................................... n_neighbors=13, total= 1.0min
# [CV] n_neighbors=16 ..................................................
# [CV] ................................... n_neighbors=13, total= 1.0min
# [CV] n_neighbors=16 ..................................................
# [CV] ................................... n_neighbors=13, total= 1.0min
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=16, total= 1.1min
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=16, total= 1.3min
# [CV] n_neighbors=19 ..................................................
# [CV] ................................... n_neighbors=16, total= 1.3min
# [CV] n_neighbors=22 ..................................................
# [CV] ................................... n_neighbors=19, total= 1.3min
# [CV] n_neighbors=22 ..................................................
# [CV] ................................... n_neighbors=19, total= 1.3min
# [CV] n_neighbors=22 ..................................................
# [CV] ................................... n_neighbors=19, total= 1.1min
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=22, total= 1.2min
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=22, total= 1.2min
# [CV] n_neighbors=25 ..................................................
# [CV] ................................... n_neighbors=22, total= 1.2min
# [CV] n_neighbors=28 ..................................................
# [CV] ................................... n_neighbors=25, total= 1.1min
# [CV] n_neighbors=28 ..................................................
# [CV] ................................... n_neighbors=25, total= 1.1min
# [CV] n_neighbors=28 ..................................................
# [CV] ................................... n_neighbors=25, total= 1.1min
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=28, total= 1.3min
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=28, total= 1.2min
# [CV] n_neighbors=31 ..................................................
# [CV] ................................... n_neighbors=28, total= 1.1min
# [CV] n_neighbors=34 ..................................................
# [CV] ................................... n_neighbors=31, total= 1.1min
# [CV] n_neighbors=34 ..................................................
# [CV] ................................... n_neighbors=31, total= 1.1min
# [CV] n_neighbors=34 ..................................................
# [CV] ................................... n_neighbors=31, total= 1.4min
# [CV] n_neighbors=37 ..................................................
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 28.9min
# [CV] ................................... n_neighbors=34, total= 1.5min
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=34, total= 1.5min
# [CV] n_neighbors=37 ..................................................
# [CV] ................................... n_neighbors=34, total= 1.5min
# [CV] n_neighbors=40 ..................................................
# [CV] ................................... n_neighbors=37, total= 1.5min
# [CV] n_neighbors=40 ..................................................
# [CV] ................................... n_neighbors=37, total= 1.5min
# [CV] n_neighbors=40 ..................................................
# [CV] ................................... n_neighbors=37, total= 1.4min
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=40, total= 1.4min
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=40, total= 1.6min
# [CV] n_neighbors=43 ..................................................
# [CV] ................................... n_neighbors=40, total= 1.5min
# [CV] n_neighbors=46 ..................................................
# [CV] ................................... n_neighbors=43, total= 1.6min
# [CV] n_neighbors=46 ..................................................
# [CV] ................................... n_neighbors=43, total= 1.7min
# [CV] n_neighbors=46 ..................................................
# [CV] ................................... n_neighbors=43, total= 1.3min
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=46, total= 1.3min
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=46, total= 1.3min
# [CV] n_neighbors=49 ..................................................
# [CV] ................................... n_neighbors=46, total= 1.4min
# [CV] n_neighbors=52 ..................................................
# [CV] ................................... n_neighbors=49, total= 1.5min
# [CV] n_neighbors=52 ..................................................
# [CV] ................................... n_neighbors=49, total= 1.5min
# [CV] n_neighbors=52 ..................................................
# [CV] ................................... n_neighbors=49, total= 1.5min
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=52, total= 1.6min
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=52, total= 1.4min
# [CV] n_neighbors=55 ..................................................
# [CV] ................................... n_neighbors=52, total= 1.4min
# [CV] n_neighbors=58 ..................................................
# [CV] ................................... n_neighbors=55, total= 1.4min
# [CV] n_neighbors=58 ..................................................
# [CV] ................................... n_neighbors=55, total= 1.4min
# [CV] n_neighbors=58 ..................................................
# [CV] ................................... n_neighbors=55, total= 1.4min
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=58, total= 1.5min
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=58, total= 1.5min
# [CV] n_neighbors=61 ..................................................
# [CV] ................................... n_neighbors=58, total= 1.4min
# [CV] n_neighbors=64 ..................................................
# [CV] ................................... n_neighbors=61, total= 1.4min
# [CV] n_neighbors=64 ..................................................
# [CV] ................................... n_neighbors=61, total= 1.4min
# [CV] n_neighbors=64 ..................................................
# [CV] ................................... n_neighbors=61, total= 1.5min
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=64, total= 1.6min
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=64, total= 1.7min
# [CV] n_neighbors=67 ..................................................
# [CV] ................................... n_neighbors=64, total= 1.8min
# [CV] n_neighbors=70 ..................................................
# [CV] ................................... n_neighbors=67, total= 2.0min
# [CV] n_neighbors=70 ..................................................
# [CV] ................................... n_neighbors=67, total= 2.1min
# [CV] n_neighbors=70 ..................................................
# [CV] ................................... n_neighbors=67, total= 1.4min
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=70, total= 1.4min
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=70, total= 1.4min
# [CV] n_neighbors=73 ..................................................
# [CV] ................................... n_neighbors=70, total= 1.4min
# [CV] n_neighbors=76 ..................................................
# [CV] ................................... n_neighbors=73, total= 1.3min
# [CV] n_neighbors=76 ..................................................
# [CV] ................................... n_neighbors=73, total= 1.3min
# [CV] n_neighbors=76 ..................................................
# [CV] ................................... n_neighbors=73, total= 1.3min
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=76, total= 1.4min
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=76, total= 1.3min
# [CV] n_neighbors=79 ..................................................
# [CV] ................................... n_neighbors=76, total= 1.3min
# [CV] n_neighbors=82 ..................................................
# [CV] ................................... n_neighbors=79, total= 1.4min
# [CV] n_neighbors=82 ..................................................
# [CV] ................................... n_neighbors=79, total= 1.4min
# [CV] n_neighbors=82 ..................................................
# [CV] ................................... n_neighbors=79, total= 1.3min
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=82, total= 1.3min
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=82, total= 1.2min
# [CV] n_neighbors=85 ..................................................
# [CV] ................................... n_neighbors=82, total= 1.3min
# [CV] n_neighbors=88 ..................................................
# [CV] ................................... n_neighbors=85, total= 1.3min
# [CV] n_neighbors=88 ..................................................
# [CV] ................................... n_neighbors=85, total= 1.4min
# [CV] n_neighbors=88 ..................................................
# [CV] ................................... n_neighbors=85, total= 1.3min
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=88, total= 1.5min
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=88, total= 1.6min
# [CV] n_neighbors=91 ..................................................
# [CV] ................................... n_neighbors=88, total= 1.5min
# [CV] n_neighbors=94 ..................................................
# [CV] ................................... n_neighbors=91, total= 1.7min
# [CV] n_neighbors=94 ..................................................
# [CV] ................................... n_neighbors=91, total= 1.8min
# [CV] n_neighbors=94 ..................................................
# [CV] ................................... n_neighbors=91, total= 1.4min
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=94, total= 1.5min
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=94, total= 1.5min
# [CV] n_neighbors=97 ..................................................
# [CV] ................................... n_neighbors=94, total= 1.5min
# [CV] n_neighbors=100 .................................................
# [CV] ................................... n_neighbors=97, total= 1.5min
# [CV] n_neighbors=100 .................................................
# [CV] ................................... n_neighbors=97, total= 1.4min
# [CV] n_neighbors=100 .................................................
# [CV] ................................... n_neighbors=97, total= 1.4min
# [CV] .................................. n_neighbors=100, total= 1.5min
# [CV] .................................. n_neighbors=100, total= 1.3min
# [CV] .................................. n_neighbors=100, total= 1.1min
# [Parallel(n_jobs=-1)]: Done 102 out of 102 | elapsed: 99.6min finished
# {'n_neighbors': 25} KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=25, p=2,
#            weights='uniform') [[3799 1402]
#  [1851 4469]]              precision    recall  f1-score   support
#
#           0       0.67      0.73      0.70      5201
#           1       0.76      0.71      0.73      6320
#
# avg / total       0.72      0.72      0.72     11521

# %% [markdown]
# ## XG Boost

# %%
model = XGBClassifier()
param_grid = [{'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['binary:logistic','reg:linear'],
              'learning_rate': [0.05,0.1], #so called `eta` value
              'max_depth': [6],
              'min_child_weight': [11],
              'silent': [1],
              'subsample': [0.8],
              'colsample_bytree': [0.7,0.8],
              'n_estimators': [5,500], #number of trees, change it to 1000 for better results
              'missing':[-999],
              'seed': [0,1337]}]
grid = GridSearchCV(model,param_grid,refit=True,verbose=2, scoring='roc_auc', n_jobs=-1)
grid.fit(X_train,y_train)
grid_predictions = grid.predict(X_test)
best_params = grid.best_params_
best_estimator = grid.best_estimator_
best_cm = confusion_matrix(y_test,grid_predictions)
best_cr = classification_report(y_test,grid_predictions)
print(best_params, best_estimator, best_cm, best_cr)
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.6s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.7s
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.7s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.6s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.5s
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   2.0s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   2.3s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   2.3s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   2.0s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.6s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.4s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.6s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.7s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  4.7min
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.7s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.9s
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.6s
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.5min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [CV] seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.3min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.3min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.3min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.7, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.3min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.5s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.3s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.2s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.3s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total=   1.2s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.2s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.2s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=binary:logistic, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.4min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.5s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.05, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.5s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total=   1.4s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.4s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.4s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=5, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total=   1.3s
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.6min
# [CV] seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=binary:logistic, subsample=0.8, total= 1.6min
# [CV] seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8
# [CV]  seed=0, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [CV]  seed=1337, colsample_bytree=0.8, max_depth=6, nthread=4, min_child_weight=11, missing=-999, n_estimators=500, learning_rate=0.1, silent=1, objective=reg:linear, subsample=0.8, total= 1.5min
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed: 18.4min finished
# {'seed': 0, 'colsample_bytree': 0.7, 'max_depth': 6, 'nthread': 4, 'min_child_weight': 11, 'missing': -999, 'n_estimators': 500, 'learning_rate': 0.05, 'subsample': 0.8, 'objective': 'reg:linear', 'silent': 1} XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.7,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=6,
#        min_child_weight=11, missing=-999, n_estimators=500, nthread=4,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=1, subsample=0.8) [[4062 1139]
#  [1411 4909]]              precision    recall  f1-score   support
#
#           0       0.74      0.78      0.76      5201
#           1       0.81      0.78      0.79      6320
#
# avg / total       0.78      0.78      0.78     11521
