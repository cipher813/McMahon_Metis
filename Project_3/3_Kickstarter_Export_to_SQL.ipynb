# %% [markdown]
# # Project 3: Predicting the Success of a Kickstarter Campaign
# A supervised learning exercise featuring logistic regression, SVM, KNN, and [Others?]

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from flask_sqlalchemy import SQLAlchemy
import os

# %%
import sys
sys.executable
# Out:
# '/Users/brianmcmahon/anaconda3/envs/tensorflow1.4/bin/python'

# %%
# env variable at tensorflow1.4 per https://conda.io/docs/user-guide/tasks/manage-environments.html#saving-environment-variables
# and https://vsupalov.com/flask-sqlalchemy-postgres/

def get_env_variable(name):
    try:
        return os.environ[name]
    except KeyError:
        message = "Expected environment variable '{}' not set.".format(name)
        raise Exception(message)

# the values of those depend on your setup
POSTGRES_URL = get_env_variable("POSTGRES_URL")
POSTGRES_USER = get_env_variable("POSTGRES_USER")
POSTGRES_PW = get_env_variable("POSTGRES_PW")
POSTGRES_DB = get_env_variable("POSTGRES_DB")

def to_str(obj):
    return str(obj).split(' ')[0]

# %%
DB_URL = 'postgresql+psycopg2://{user}:{pw}@{url}/{db}'.format(user=POSTGRES_USER,pw=POSTGRES_PW,url=POSTGRES_URL,db=POSTGRES_DB)

# %%
engine_var = DB_URL
engine = create_engine(engine_var)

# %%
# df = pd.read_csv('data/Kickstarter_2018-01-12T10_20_09_196Z/Kickstarter048.csv')

df = pd.read_csv('data/ks-projects-201801.csv') # From kaggle dataset at https://www.kaggle.com/kemical/kickstarter-projects
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
df['deadline'] = pd.to_datetime(df['deadline'])
df['launched'] = pd.to_datetime(df['launched']) 
df['launched'] = df['launched'].apply(lambda x: x.strftime('%Y-%m-%d'))
df['launched'] = pd.to_datetime(df['launched']) 
df = df.sort_values(['deadline'], ascending=[False])
df['campaign_length'] = (df['deadline'] - df['launched']).apply(to_str)
df['pct_goal_achieved'] = round((df['usd_pledged_real'] / df['usd_goal_real'])*100,1)
# df = df.set_index('ID')
print(df.shape)
df.head()
# Out:
# (378661, 17)
#                 ID                        name category main_category  \
# 226982    22387366                Nerd Collect     Apps    Technology
# 7164    1036415983               Aikyam : Onnu    Music         Music
# 180250  1916988520   Back in Black Hills Movie    Drama  Film & Video
# 71730   1365286494         From the Wilderness    Drama  Film & Video
# 292034    55596200  Plateforme de statistiques     Apps    Technology
#
#        currency   deadline      goal   launched  pledged state  backers  \
# 226982      GBP 2018-03-03  150000.0 2018-01-02      0.0  live        0
# 7164        USD 2018-03-03   10000.0 2018-01-02    174.0  live        3
# 180250      USD 2018-03-03    5500.0 2018-01-02      0.0  live        0
# 71730       USD 2018-03-02    2500.0 2018-01-01    482.0  live       19
# 292034      EUR 2018-03-02    9000.0 2018-01-01      0.0  live        0
#
#        country  usd pledged  usd_pledged_real  usd_goal_real campaign_length  \
# 226982      GB          0.0               0.0      204596.60              60
# 7164        US        174.0             174.0       10000.00              60
# 180250      US          0.0               0.0        5500.00              60
# 71730       US          0.0             482.0        2500.00              60
# 292034      FR          0.0               0.0       10923.26              60
#
#         pct_goal_achieved
# 226982                0.0
# 7164                  1.7
# 180250                0.0
# 71730                19.3
# 292034                0.0

# %%
# remove canceled, undefined, live and suspended
df = df[(df['state'] == 'successful') | (df['state'] == 'failed')]
df = pd.DataFrame(df)
start_date = pd.to_datetime('2012-01-01') 
df = df[df['launched'] >= start_date] # filter from start date to current
print(df.shape)
df.tail()
# Out:
# (296870, 17)
#                 ID                                               name  \
# 109284  1555346070        Decentralized Dance Party- HOUSTON EDITION!
# 323061   715382757                      "UPLDR" - A Sci-Fi Short Film
# 171673  1873328240                                 #yougotnogame film
# 361999   914600915  "Drifting Into The Sublime" Ken Verheecke's Ne...
# 181280  1922604394                                THE LAST FIVE YEARS
#
#            category main_category currency   deadline     goal   launched  \
# 109284   Public Art           Art      USD 2012-01-14    999.0 2012-01-10
# 323061       Shorts  Film & Video      USD 2012-01-13  15000.0 2012-01-05
# 171673       Shorts  Film & Video      USD 2012-01-09    500.0 2012-01-02
# 361999  World Music         Music      USD 2012-01-08   6000.0 2012-01-02
# 181280      Theater       Theater      USD 2012-01-07   1000.0 2012-01-03
#
#          pledged       state  backers country  usd pledged  usd_pledged_real  \
# 109284   1057.07  successful       40      US      1057.07           1057.07
# 323061  15031.00  successful       36      US     15031.00          15031.00
# 171673    736.00  successful       14      US       736.00            736.00
# 361999   4311.00      failed       28      US      4311.00           4311.00
# 181280   2145.00  successful       24      US      2145.00           2145.00
#
#         usd_goal_real campaign_length  pct_goal_achieved
# 109284          999.0               4              105.8
# 323061        15000.0               8              100.2
# 171673          500.0               7              147.2
# 361999         6000.0               6               71.9
# 181280         1000.0               4              214.5

# %%
# df['ID'] = df['ID'].apply(to_str)
df['deadline'] = df['deadline'].apply(to_str)
df['launched'] = df['launched'].apply(to_str)
df['idx'] = df['ID']
df = df.set_index('idx')

# %%
# Prep for categorical analysis
# df.main_category = pd.Categorical(df.main_category) 
# df['main_category_code'] = df.main_category.cat.codes

# df.country = pd.Categorical(df.country) 
# df['country_code'] = df.country.cat.codes

# df.currency = pd.Categorical(df.currency) 
# df['currency_code'] = df.currency.cat.codes

# df.state = pd.Categorical(df.state) 
# df['state_code'] = df.state.cat.codes

# df.head(100)

# %%
# df['main_category'] = pd.get_dummies('main_category')
# df.columns

# %%
df_dummies = pd.get_dummies(df[['state','main_category','country','currency']],drop_first=True)
# df['state'] = pd.get_dummies(df['state'])
# df['main_category'] = pd.get_dummies(df['main_category'])
# df['country'] = pd.get_dummies(df['country'])
# df['currency'] = pd.get_dummies(df['currency'])
df['ID'].head()
# Out:
# idx
# 1031685482    1031685482
# 1176736360    1176736360
# 1894703097    1894703097
# 311863059      311863059
# 2076121120    2076121120
# Name: ID, dtype: int64

# %%
df = df_dummies.merge(df,how='inner',left_index=True, right_index=True)

df.columns
# Out:
# Index(['state_successful', 'main_category_Comics', 'main_category_Crafts',
#        'main_category_Dance', 'main_category_Design', 'main_category_Fashion',
#        'main_category_Film & Video', 'main_category_Food',
#        'main_category_Games', 'main_category_Journalism',
#        'main_category_Music', 'main_category_Photography',
#        'main_category_Publishing', 'main_category_Technology',
#        'main_category_Theater', 'country_AU', 'country_BE', 'country_CA',
#        'country_CH', 'country_DE', 'country_DK', 'country_ES', 'country_FR',
#        'country_GB', 'country_HK', 'country_IE', 'country_IT', 'country_JP',
#        'country_LU', 'country_MX', 'country_N,0"', 'country_NL', 'country_NO',
#        'country_NZ', 'country_SE', 'country_SG', 'country_US', 'currency_CAD',
#        'currency_CHF', 'currency_DKK', 'currency_EUR', 'currency_GBP',
#        'currency_HKD', 'currency_JPY', 'currency_MXN', 'currency_NOK',
#        'currency_NZD', 'currency_SEK', 'currency_SGD', 'currency_USD', 'ID',
#        'name', 'category', 'main_category', 'currency', 'deadline', 'goal',
#        'launched', 'pledged', 'state', 'backers', 'country', 'usd pledged',
#        'usd_pledged_real', 'usd_goal_real', 'campaign_length',
#        'pct_goal_achieved'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296870 entries, 1031685482 to 1922604394
# Data columns (total 67 columns):
# state_successful              296870 non-null uint8
# main_category_Comics          296870 non-null uint8
# main_category_Crafts          296870 non-null uint8
# main_category_Dance           296870 non-null uint8
# main_category_Design          296870 non-null uint8
# main_category_Fashion         296870 non-null uint8
# main_category_Film & Video    296870 non-null uint8
# main_category_Food            296870 non-null uint8
# main_category_Games           296870 non-null uint8
# main_category_Journalism      296870 non-null uint8
# main_category_Music           296870 non-null uint8
# main_category_Photography     296870 non-null uint8
# main_category_Publishing      296870 non-null uint8
# main_category_Technology      296870 non-null uint8
# main_category_Theater         296870 non-null uint8
# country_AU                    296870 non-null uint8
# country_BE                    296870 non-null uint8
# country_CA                    296870 non-null uint8
# country_CH                    296870 non-null uint8
# country_DE                    296870 non-null uint8
# country_DK                    296870 non-null uint8
# country_ES                    296870 non-null uint8
# country_FR                    296870 non-null uint8
# country_GB                    296870 non-null uint8
# country_HK                    296870 non-null uint8
# country_IE                    296870 non-null uint8
# country_IT                    296870 non-null uint8
# country_JP                    296870 non-null uint8
# country_LU                    296870 non-null uint8
# country_MX                    296870 non-null uint8
# country_N,0"                  296870 non-null uint8
# country_NL                    296870 non-null uint8
# country_NO                    296870 non-null uint8
# country_NZ                    296870 non-null uint8
# country_SE                    296870 non-null uint8
# country_SG                    296870 non-null uint8
# country_US                    296870 non-null uint8
# currency_CAD                  296870 non-null uint8
# currency_CHF                  296870 non-null uint8
# currency_DKK                  296870 non-null uint8
# currency_EUR                  296870 non-null uint8
# currency_GBP                  296870 non-null uint8
# currency_HKD                  296870 non-null uint8
# currency_JPY                  296870 non-null uint8
# currency_MXN                  296870 non-null uint8
# currency_NOK                  296870 non-null uint8
# currency_NZD                  296870 non-null uint8
# currency_SEK                  296870 non-null uint8
# currency_SGD                  296870 non-null uint8
# currency_USD                  296870 non-null uint8
# ID                            296870 non-null int64
# name                          296868 non-null object
# category                      296870 non-null object
# main_category                 296870 non-null object
# currency                      296870 non-null object
# deadline                      296870 non-null object
# goal                          296870 non-null float64
# launched                      296870 non-null object
# pledged                       296870 non-null float64
# state                         296870 non-null object
# backers                       296870 non-null int64
# country                       296870 non-null object
# usd pledged                   296660 non-null float64
# usd_pledged_real              296870 non-null float64
# usd_goal_real                 296870 non-null float64
# campaign_length               296870 non-null object
# pct_goal_achieved             296870 non-null float64
# dtypes: float64(6), int64(2), object(9), uint8(50)
# memory usage: 64.9+ MB

# %%
df.head()
# Out:
#             state_successful  main_category_Comics  main_category_Crafts  \
# idx
# 1031685482                 1                     0                     0
# 1176736360                 1                     0                     0
# 1894703097                 1                     0                     0
# 311863059                  1                     0                     0
# 2076121120                 0                     0                     0
#
#             main_category_Dance  main_category_Design  main_category_Fashion  \
# idx
# 1031685482                    0                     0                      0
# 1176736360                    0                     0                      0
# 1894703097                    0                     0                      0
# 311863059                     0                     0                      0
# 2076121120                    0                     0                      0
#
#             main_category_Film & Video  main_category_Food  \
# idx
# 1031685482                           0                   0
# 1176736360                           0                   0
# 1894703097                           0                   0
# 311863059                            0                   0
# 2076121120                           0                   1
#
#             main_category_Games  main_category_Journalism        ...          \
# idx                                                              ...
# 1031685482                    0                         0        ...
# 1176736360                    0                         0        ...
# 1894703097                    0                         0        ...
# 311863059                     0                         0        ...
# 2076121120                    0                         0        ...
#
#               launched   pledged       state  backers  country  usd pledged  \
# idx
# 1031685482  2017-12-06   6083.00  successful      133       US       1054.0
# 1176736360  2017-11-30  11169.56  successful      177       US        650.0
# 1894703097  2017-11-28  25417.20  successful      168       DE          0.0
# 311863059   2017-12-09   1743.00  successful       39       US          0.0
# 2076121120  2017-11-03      1.00      failed        1       US          0.0
#
#             usd_pledged_real  usd_goal_real  campaign_length  \
# idx
# 1031685482           6083.00         2000.0               27
# 1176736360          11169.56        10000.0               33
# 1894703097          30615.02        30112.5               35
# 311863059            1743.00         1000.0               24
# 2076121120              1.00       200000.0               60
#
#             pct_goal_achieved
# idx
# 1031685482              304.2
# 1176736360              111.7
# 1894703097              101.7
# 311863059               174.3
# 2076121120                0.0
#
# [5 rows x 67 columns]

# %%
try:
    df.to_sql("kickstarter_data", engine, chunksize=20000, if_exists='replace')
except Exception as e:
    print(e)
    pass

# Temporary fix:
# df.to_pickle('data/kickstarter_data.pkl')
# df.to_csv('data/kickstarter_data.csv')
# Out:
# (psycopg2.OperationalError) SSL SYSCALL error: EOF detected
#  (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# ## State of Success [this should now be covered in EDA]

# %%
# df_state = df.groupby(["state"]).count().sort_values(['name'], ascending=[False])
# df_state = pd.DataFrame(df_state, columns={'name'})
# print(df_state.shape)
# df_state

# %%
# df_state = df.groupby(["state"]).sum().sort_values(['usd pledged'], ascending=[False])
# df_state = pd.DataFrame(df_state, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
# print(df_state.shape)
# df_state

# %%
# df_country = df.groupby(["country"]).count().sort_values(['name'], ascending=[False])
# df_country = pd.DataFrame(df_country, columns={'name'})
# print(df_country.shape)
# df_country

# %%
# df_country = df.groupby(["country"]).sum().sort_values(['usd pledged'], ascending=[False])
# df_country = pd.DataFrame(df_country, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
# print(df_country.shape)
# df_country

# %%
# df_currency = df.groupby(["currency"]).count().sort_values(['name'], ascending=[False])
# df_currency = pd.DataFrame(df_currency, columns={'name'})
# print(df_currency.shape)
# df_currency

# %%
# df_currency = df.groupby(["currency"]).sum().sort_values(['usd pledged'], ascending=[False])
# df_currency = pd.DataFrame(df_currency, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
# print(df_currency.shape)
# df_currency

# %%
# df_main_category = df.groupby(["main_category"]).count().sort_values(['name'], ascending=[False])
# df_main_category = pd.DataFrame(df_main_category, columns={'name'})
# print(df_main_category.shape)
# df_main_category

# %%
# df_main_category = df.groupby(["main_category"]).sum().sort_values(['usd pledged'], ascending=[False])
# df_main_category = pd.DataFrame(df_main_category, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
# print(df_main_category.shape)
# df_main_category

# %%
# df_category = df.groupby(["category"]).count().sort_values(['name'], ascending=[False])
# print(df_category.shape)
# df_category

# %%
# df_category = df.groupby(["category"]).sum().sort_values(['usd pledged'], ascending=[False])
# df_category = pd.DataFrame(df_category, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
# print(df_category.shape)
# df_category

# %%
# df2 = pd.read_csv('data/Kickstarter_2018-01-12T10_20_09_196Z/Kickstarter048.csv')
# df2.head()
