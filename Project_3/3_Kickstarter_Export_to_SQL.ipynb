# %% [markdown]
# # Project 3: Predicting the Success of a Kickstarter Campaign
# A supervised learning exercise featuring logistic regression, SVM, KNN, and [Others?]

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
from flask_sqlalchemy import SQLAlchemy
import os

# %%
import sys
sys.executable
# Out:
# '/Users/brianmcmahon/anaconda3/envs/tensorflow1.4/bin/python'

# %%
# env variable at tensorflow1.4 per https://conda.io/docs/user-guide/tasks/manage-environments.html#saving-environment-variables
# and https://vsupalov.com/flask-sqlalchemy-postgres/

def get_env_variable(name):
    try:
        return os.environ[name]
    except KeyError:
        message = "Expected environment variable '{}' not set.".format(name)
        raise Exception(message)

# the values of those depend on your setup
POSTGRES_URL = get_env_variable("POSTGRES_URL")
POSTGRES_USER = get_env_variable("POSTGRES_USER")
POSTGRES_PW = get_env_variable("POSTGRES_PW")
POSTGRES_DB = get_env_variable("POSTGRES_DB")

def to_str(obj):
    return str(obj).split(' ')[0]

# %%
DB_URL = 'postgresql+psycopg2://{user}:{pw}@{url}/{db}'.format(user=POSTGRES_USER,pw=POSTGRES_PW,url=POSTGRES_URL,db=POSTGRES_DB)

# app.config['SQLALCHEMY_DATABASE_URI'] = DB_URL
# app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False # silence the deprecation warning

# db = SQLAlchemy(app)

# %%
engine_var = DB_URL
engine = create_engine(engine_var)

# %%
# pd.read_sql_query('''SELECT * FROM allstarfull LIMIT 5''',engine)

# %%
df = pd.read_csv('data/ks-projects-201801.csv') # From kaggle dataset at https://www.kaggle.com/kemical/kickstarter-projects
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %%
df['deadline'] = pd.to_datetime(df['deadline'])
df['launched'] = pd.to_datetime(df['launched']) 
df['launched'] = df['launched'].apply(lambda x: x.strftime('%Y-%m-%d'))
df['launched'] = pd.to_datetime(df['launched']) 
df = df.sort_values(['deadline'], ascending=[False])
df['campaign_length'] = (df['deadline'] - df['launched']).apply(to_str)
df['pct_goal_achieved'] = (df['usd_pledged_real'] / df['usd_goal_real'])*100
# df = df.set_index('ID')
print(df.shape)
df.head()
# Out:
# (378661, 17)
#                 ID                        name category main_category  \
# 226982    22387366                Nerd Collect     Apps    Technology
# 7164    1036415983               Aikyam : Onnu    Music         Music
# 180250  1916988520   Back in Black Hills Movie    Drama  Film & Video
# 71730   1365286494         From the Wilderness    Drama  Film & Video
# 292034    55596200  Plateforme de statistiques     Apps    Technology
#
#        currency   deadline      goal   launched  pledged state  backers  \
# 226982      GBP 2018-03-03  150000.0 2018-01-02      0.0  live        0
# 7164        USD 2018-03-03   10000.0 2018-01-02    174.0  live        3
# 180250      USD 2018-03-03    5500.0 2018-01-02      0.0  live        0
# 71730       USD 2018-03-02    2500.0 2018-01-01    482.0  live       19
# 292034      EUR 2018-03-02    9000.0 2018-01-01      0.0  live        0
#
#        country  usd pledged  usd_pledged_real  usd_goal_real campaign_length  \
# 226982      GB          0.0               0.0      204596.60              60
# 7164        US        174.0             174.0       10000.00              60
# 180250      US          0.0               0.0        5500.00              60
# 71730       US          0.0             482.0        2500.00              60
# 292034      FR          0.0               0.0       10923.26              60
#
#         pct_goal_achieved
# 226982               0.00
# 7164                 1.74
# 180250               0.00
# 71730               19.28
# 292034               0.00

# %%
# remove canceled, undefined, live and suspended
df = df[(df['state'] == 'successful') | (df['state'] == 'failed')]
df = pd.DataFrame(df)
start_date = pd.to_datetime('2017-06-30') 
df = df[df['launched'] >= start_date] # filter from start date to current
print(df.shape)
df.tail()
# Out:
# (19291, 17)
#                 ID                                               name  \
# 244899   315499236  Help struggling brooklyn fashion designer with...
# 197010  2003107805                            Die Cut Python Stickers
# 378594   999667180                       VARIANT WARS - The Prisoners
# 28603   1145118881                                  Softball Ring Box
# 51419   1261713735                           101 Piano Songs. 1 Album
#
#                category main_category currency   deadline    goal   launched  \
# 244899          Apparel       Fashion      USD 2017-07-07  3500.0 2017-06-30
# 197010     Illustration           Art      USD 2017-07-07   200.0 2017-06-30
# 378594          Fiction    Publishing      USD 2017-07-07   325.0 2017-06-30
# 28603             Games         Games      USD 2017-07-07   150.0 2017-07-02
# 51419   Classical Music         Music      USD 2017-07-05  1000.0 2017-07-02
#
#         pledged       state  backers country  usd pledged  usd_pledged_real  \
# 244899      0.0      failed        0      US          0.0               0.0
# 197010    158.0      failed       30      US          0.0             158.0
# 378594    425.0  successful        7      US        425.0             425.0
# 28603      65.0      failed        1      US         65.0              65.0
# 51419      33.0      failed        3      US         32.0              33.0
#
#         usd_goal_real campaign_length  pct_goal_achieved
# 244899         3500.0               7           0.000000
# 197010          200.0               7          79.000000
# 378594          325.0               7         130.769231
# 28603           150.0               5          43.333333
# 51419          1000.0               3           3.300000

# %%
df['ID'] = df['ID'].apply(to_str)
df['deadline'] = df['deadline'].apply(to_str)
df['launched'] = df['launched'].apply(to_str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19291 entries, 6201 to 51419
# Data columns (total 17 columns):
# ID                   19291 non-null object
# name                 19291 non-null object
# category             19291 non-null object
# main_category        19291 non-null object
# currency             19291 non-null object
# deadline             19291 non-null object
# goal                 19291 non-null float64
# launched             19291 non-null object
# pledged              19291 non-null float64
# state                19291 non-null object
# backers              19291 non-null int64
# country              19291 non-null object
# usd pledged          19291 non-null float64
# usd_pledged_real     19291 non-null float64
# usd_goal_real        19291 non-null float64
# campaign_length      19291 non-null object
# pct_goal_achieved    19291 non-null float64
# dtypes: float64(6), int64(1), object(10)
# memory usage: 2.6+ MB

# %%
try:
    df.to_sql("kickstarter_data", engine, chunksize=20000, if_exists='replace')
except Exception as e:
    print(e)
    pass

# Temporary fix:
# df.to_pickle('data/kickstarter_data.pkl')
# df.to_csv('data/kickstarter_data.csv')

# %% [markdown]
# ## State of Success [this should now be covered in EDA]

# %%
df_state = df.groupby(["state"]).count().sort_values(['name'], ascending=[False])
df_state = pd.DataFrame(df_state, columns={'name'})
print(df_state.shape)
df_state
# Out:
# (2, 1)
#              name
# state
# failed      10923
# successful   8368

# %%
df_state = df.groupby(["state"]).sum().sort_values(['usd pledged'], ascending=[False])
df_state = pd.DataFrame(df_state, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_state.shape)
df_state
# Out:
# (2, 3)
#             usd_pledged_real  usd_goal_real  usd pledged
# state
# successful      2.493829e+08   8.123888e+07  45388879.68
# failed          1.338983e+07   7.931090e+08   3238970.87

# %%
df_country = df.groupby(["country"]).count().sort_values(['name'], ascending=[False])
df_country = pd.DataFrame(df_country, columns={'name'})
print(df_country.shape)
df_country
# Out:
# (22, 1)
#           name
# country
# US       12204
# GB        2207
# CA         962
# AU         581
# DE         519
# MX         467
# FR         353
# IT         329
# ES         279
# NL         216
# HK         200
# SG         181
# SE         152
# NZ         138
# CH          95
# DK          92
# IE          86
# AT          77
# BE          71
# NO          48
# JP          23
# LU          11

# %%
df_country = df.groupby(["country"]).sum().sort_values(['usd pledged'], ascending=[False])
df_country = pd.DataFrame(df_country, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_country.shape)
df_country
# Out:
# (22, 3)
#          usd_pledged_real  usd_goal_real  usd pledged
# country
# US           1.872663e+08   6.723174e+08  34464582.72
# GB           1.871978e+07   4.608401e+07   3834655.55
# AU           5.774700e+06   1.419635e+07   1476295.43
# CA           7.231933e+06   3.122999e+07   1231199.71
# FR           5.389620e+06   6.461087e+06   1153789.35
# NL           5.824917e+06   4.211652e+06   1054833.26
# DE           6.270310e+06   1.847728e+07    954465.39
# SE           2.641517e+06   1.554980e+07    792333.96
# HK           5.019316e+06   4.539081e+06    629163.34
# ES           2.572853e+06   7.151126e+06    564411.79
# CH           3.459366e+06   3.356332e+06    494245.22
# IT           1.596003e+06   2.832612e+07    418781.51
# NZ           1.178904e+06   1.463891e+06    336151.89
# SG           1.741028e+06   2.690394e+06    293335.71
# BE           7.303084e+05   3.475950e+06    198005.05
# DK           9.880094e+05   1.471866e+06    194944.11
# AT           4.275574e+06   3.536380e+06    173450.13
# IE           7.417760e+05   1.138088e+06    159180.95
# MX           7.959577e+05   6.931170e+06     94257.47
# NO           2.282353e+05   1.066281e+06     64938.03
# LU           2.414456e+05   3.766586e+05     23459.10
# JP           8.481102e+04   2.969887e+05     21370.88

# %%
df_currency = df.groupby(["currency"]).count().sort_values(['name'], ascending=[False])
df_currency = pd.DataFrame(df_currency, columns={'name'})
print(df_currency.shape)
df_currency
# Out:
# (14, 1)
#            name
# currency
# USD       12204
# GBP        2207
# EUR        1941
# CAD         962
# AUD         581
# MXN         467
# HKD         200
# SGD         181
# SEK         152
# NZD         138
# CHF          95
# DKK          92
# NOK          48
# JPY          23

# %%
df_currency = df.groupby(["currency"]).sum().sort_values(['usd pledged'], ascending=[False])
df_currency = pd.DataFrame(df_currency, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_currency.shape)
df_currency
# Out:
# (14, 3)
#           usd_pledged_real  usd_goal_real  usd pledged
# currency
# USD           1.872663e+08   6.723174e+08  34464582.72
# EUR           2.764281e+07   7.315434e+07   4700376.53
# GBP           1.871978e+07   4.608401e+07   3834655.55
# AUD           5.774700e+06   1.419635e+07   1476295.43
# CAD           7.231933e+06   3.122999e+07   1231199.71
# SEK           2.641517e+06   1.554980e+07    792333.96
# HKD           5.019316e+06   4.539081e+06    629163.34
# CHF           3.459366e+06   3.356332e+06    494245.22
# NZD           1.178904e+06   1.463891e+06    336151.89
# SGD           1.741028e+06   2.690394e+06    293335.71
# DKK           9.880094e+05   1.471866e+06    194944.11
# MXN           7.959577e+05   6.931170e+06     94257.47
# NOK           2.282353e+05   1.066281e+06     64938.03
# JPY           8.481102e+04   2.969887e+05     21370.88

# %%
df_main_category = df.groupby(["main_category"]).count().sort_values(['name'], ascending=[False])
df_main_category = pd.DataFrame(df_main_category, columns={'name'})
print(df_main_category.shape)
df_main_category
# Out:
# (15, 1)
#                name
# main_category
# Games          2541
# Design         2127
# Technology     2081
# Publishing     2005
# Film & Video   1943
# Music          1774
# Fashion        1731
# Art            1466
# Food           1167
# Comics          824
# Crafts          555
# Photography     386
# Theater         322
# Journalism      228
# Dance           141

# %%
df_main_category = df.groupby(["main_category"]).sum().sort_values(['usd pledged'], ascending=[False])
df_main_category = pd.DataFrame(df_main_category, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_main_category.shape)
df_main_category
# Out:
# (15, 3)
#                usd_pledged_real  usd_goal_real  usd pledged
# main_category
# Games               70608172.84   4.814846e+07  16012906.59
# Design              66428025.84   5.219732e+07  11227552.65
# Technology          56029162.80   1.065280e+08   9839204.61
# Film & Video        13787683.40   3.962250e+08   1888845.34
# Publishing          10911971.51   2.271882e+07   1824525.49
# Fashion              9388519.35   4.128178e+07   1816747.06
# Comics               5644728.90   5.096887e+06   1352001.51
# Art                  6768373.09   1.107441e+08   1263911.07
# Music                8672763.71   2.503947e+07   1218577.27
# Food                 7374668.61   3.110974e+07   1165028.68
# Photography          2583636.32   4.286490e+06    471923.05
# Crafts               1701708.68   4.763957e+06    276885.11
# Theater              1635810.68   9.136002e+06    150778.29
# Journalism            659631.90   1.596864e+07     71570.13
# Dance                 577835.15   1.103193e+06     47393.70

# %%
df_category = df.groupby(["category"]).count().sort_values(['name'], ascending=[False])
print(df_category.shape)
df_category
# Out:
# (157, 16)
#                      ID  name  main_category  currency  deadline  goal  \
# category
# Product Design     1675  1675           1675      1675      1675  1675
# Tabletop Games     1281  1281           1281      1281      1281  1281
# Music               613   613            613       613       613   613
# Apparel             595   595            595       595       595   595
# Video Games         556   556            556       556       556   556
# Accessories         528   528            528       528       528   528
# Apps                503   503            503       503       503   503
# Art                 478   478            478       478       478   478
# Children's Books    427   427            427       427       427   427
# Documentary         381   381            381       381       381   381
# Comic Books         355   355            355       355       355   355
# Illustration        354   354            354       354       354   354
# Publishing          343   343            343       343       343   343
# Technology          330   330            330       330       330   330
# Fiction             309   309            309       309       309   309
# Food                299   299            299       299       299   299
# Nonfiction          297   297            297       297       297   297
# Playing Cards       296   296            296       296       296   296
# Web                 292   292            292       292       292   292
# Film & Video        291   291            291       291       291   291
# Crafts              272   272            272       272       272   272
# Gadgets             251   251            251       251       251   251
# Design              238   238            238       238       238   238
# Shorts              234   234            234       234       234   234
# Fashion             226   226            226       226       226   226
# Drinks              194   194            194       194       194   194
# Comedy              194   194            194       194       194   194
# Graphic Novels      193   193            193       193       193   193
# Games               188   188            188       188       188   188
# Restaurants         178   178            178       178       178   178
# ...                 ...   ...            ...       ...       ...   ...
# Family               16    16             16        16        16    16
# Printing             16    16             16        16        16    16
# Literary Journals    16    16             16        16        16    16
# Makerspaces          15    15             15        15        15    15
# Couture              15    15             15        15        15    15
# Movie Theaters       14    14             14        14        14    14
# Weaving              13    13             13        13        13    13
# Community Gardens    13    13             13        13        13    13
# Pet Fashion          12    12             12        12        12    12
# Animals              12    12             12        12        12    12
# Puzzles              12    12             12        12        12    12
# Literary Spaces      12    12             12        12        12    12
# Blues                12    12             12        12        12    12
# Romance              11    11             11        11        11    11
# Knitting             11    11             11        11        11    11
# Embroidery           11    11             11        11        11    11
# Typography            9     9              9         9         9     9
# Photo                 9     9              9         9         9     9
# Pottery               9     9              9         9         9     9
# Workshops             8     8              8         8         8     8
# Civic Design          8     8              8         8         8     8
# Video Art             7     7              7         7         7     7
# Letterpress           7     7              7         7         7     7
# Bacon                 6     6              6         6         6     6
# Latin                 6     6              6         6         6     6
# Translations          5     5              5         5         5     5
# Residencies           4     4              4         4         4     4
# Glass                 4     4              4         4         4     4
# Crochet               4     4              4         4         4     4
# Quilts                3     3              3         3         3     3
#
#                    launched  pledged  state  backers  country  usd pledged  \
# category
# Product Design         1675     1675   1675     1675     1675         1675
# Tabletop Games         1281     1281   1281     1281     1281         1281
# Music                   613      613    613      613      613          613
# Apparel                 595      595    595      595      595          595
# Video Games             556      556    556      556      556          556
# Accessories             528      528    528      528      528          528
# Apps                    503      503    503      503      503          503
# Art                     478      478    478      478      478          478
# Children's Books        427      427    427      427      427          427
# Documentary             381      381    381      381      381          381
# Comic Books             355      355    355      355      355          355
# Illustration            354      354    354      354      354          354
# Publishing              343      343    343      343      343          343
# Technology              330      330    330      330      330          330
# Fiction                 309      309    309      309      309          309
# Food                    299      299    299      299      299          299
# Nonfiction              297      297    297      297      297          297
# Playing Cards           296      296    296      296      296          296
# Web                     292      292    292      292      292          292
# Film & Video            291      291    291      291      291          291
# Crafts                  272      272    272      272      272          272
# Gadgets                 251      251    251      251      251          251
# Design                  238      238    238      238      238          238
# Shorts                  234      234    234      234      234          234
# Fashion                 226      226    226      226      226          226
# Drinks                  194      194    194      194      194          194
# Comedy                  194      194    194      194      194          194
# Graphic Novels          193      193    193      193      193          193
# Games                   188      188    188      188      188          188
# Restaurants             178      178    178      178      178          178
# ...                     ...      ...    ...      ...      ...          ...
# Family                   16       16     16       16       16           16
# Printing                 16       16     16       16       16           16
# Literary Journals        16       16     16       16       16           16
# Makerspaces              15       15     15       15       15           15
# Couture                  15       15     15       15       15           15
# Movie Theaters           14       14     14       14       14           14
# Weaving                  13       13     13       13       13           13
# Community Gardens        13       13     13       13       13           13
# Pet Fashion              12       12     12       12       12           12
# Animals                  12       12     12       12       12           12
# Puzzles                  12       12     12       12       12           12
# Literary Spaces          12       12     12       12       12           12
# Blues                    12       12     12       12       12           12
# Romance                  11       11     11       11       11           11
# Knitting                 11       11     11       11       11           11
# Embroidery               11       11     11       11       11           11
# Typography                9        9      9        9        9            9
# Photo                     9        9      9        9        9            9
# Pottery                   9        9      9        9        9            9
# Workshops                 8        8      8        8        8            8
# Civic Design              8        8      8        8        8            8
# Video Art                 7        7      7        7        7            7
# Letterpress               7        7      7        7        7            7
# Bacon                     6        6      6        6        6            6
# Latin                     6        6      6        6        6            6
# Translations              5        5      5        5        5            5
# Residencies               4        4      4        4        4            4
# Glass                     4        4      4        4        4            4
# Crochet                   4        4      4        4        4            4
# Quilts                    3        3      3        3        3            3
#
#                    usd_pledged_real  usd_goal_real  campaign_length  \
# category
# Product Design                 1675           1675             1675
# Tabletop Games                 1281           1281             1281
# Music                           613            613              613
# Apparel                         595            595              595
# Video Games                     556            556              556
# Accessories                     528            528              528
# Apps                            503            503              503
# Art                             478            478              478
# Children's Books                427            427              427
# Documentary                     381            381              381
# Comic Books                     355            355              355
# Illustration                    354            354              354
# Publishing                      343            343              343
# Technology                      330            330              330
# Fiction                         309            309              309
# Food                            299            299              299
# Nonfiction                      297            297              297
# Playing Cards                   296            296              296
# Web                             292            292              292
# Film & Video                    291            291              291
# Crafts                          272            272              272
# Gadgets                         251            251              251
# Design                          238            238              238
# Shorts                          234            234              234
# Fashion                         226            226              226
# Drinks                          194            194              194
# Comedy                          194            194              194
# Graphic Novels                  193            193              193
# Games                           188            188              188
# Restaurants                     178            178              178
# ...                             ...            ...              ...
# Family                           16             16               16
# Printing                         16             16               16
# Literary Journals                16             16               16
# Makerspaces                      15             15               15
# Couture                          15             15               15
# Movie Theaters                   14             14               14
# Weaving                          13             13               13
# Community Gardens                13             13               13
# Pet Fashion                      12             12               12
# Animals                          12             12               12
# Puzzles                          12             12               12
# Literary Spaces                  12             12               12
# Blues                            12             12               12
# Romance                          11             11               11
# Knitting                         11             11               11
# Embroidery                       11             11               11
# Typography                        9              9                9
# Photo                             9              9                9
# Pottery                           9              9                9
# Workshops                         8              8                8
# Civic Design                      8              8                8
# Video Art                         7              7                7
# Letterpress                       7              7                7
# Bacon                             6              6                6
# Latin                             6              6                6
# Translations                      5              5                5
# Residencies                       4              4                4
# Glass                             4              4                4
# Crochet                           4              4                4
# Quilts                            3              3                3
#
#                    pct_goal_achieved
# category
# Product Design                  1675
# Tabletop Games                  1281
# Music                            613
# Apparel                          595
# Video Games                      556
# Accessories                      528
# Apps                             503
# Art                              478
# Children's Books                 427
# Documentary                      381
# Comic Books                      355
# Illustration                     354
# Publishing                       343
# Technology                       330
# Fiction                          309
# Food                             299
# Nonfiction                       297
# Playing Cards                    296
# Web                              292
# Film & Video                     291
# Crafts                           272
# Gadgets                          251
# Design                           238
# Shorts                           234
# Fashion                          226
# Drinks                           194
# Comedy                           194
# Graphic Novels                   193
# Games                            188
# Restaurants                      178
# ...                              ...
# Family                            16
# Printing                          16
# Literary Journals                 16
# Makerspaces                       15
# Couture                           15
# Movie Theaters                    14
# Weaving                           13
# Community Gardens                 13
# Pet Fashion                       12
# Animals                           12
# Puzzles                           12
# Literary Spaces                   12
# Blues                             12
# Romance                           11
# Knitting                          11
# Embroidery                        11
# Typography                         9
# Photo                              9
# Pottery                            9
# Workshops                          8
# Civic Design                       8
# Video Art                          7
# Letterpress                        7
# Bacon                              6
# Latin                              6
# Translations                       5
# Residencies                        4
# Glass                              4
# Crochet                            4
# Quilts                             3
#
# [157 rows x 16 columns]

# %%
df_category = df.groupby(["category"]).sum().sort_values(['usd pledged'], ascending=[False])
df_category = pd.DataFrame(df_category, columns={'usd pledged', 'usd_pledged_real','usd_goal_real'})
print(df_category.shape)
df_category
# Out:
# (157, 3)
#                    usd_pledged_real  usd_goal_real  usd pledged
# category
# Tabletop Games          59007489.07    15384499.07  13415509.16
# Product Design          54426113.02    34575051.56   9595443.55
# Hardware                11177130.20    10072078.60   2111388.14
# Technology               8161553.50    27381255.88   1930757.19
# Wearables                8721065.16     4006337.79   1748151.62
# Design                   9818868.51     4752523.21   1463699.06
# Video Games              6294961.38    17368431.54   1347752.60
# Gadgets                  6038475.80     7572407.85    941613.56
# Apparel                  3609987.18     9163228.58    663330.96
# 3D Printing              2952991.02     1519064.73    662054.09
# Playing Cards            2595797.13     2159766.53    633707.16
# Art                      2201436.71     4082721.23    536184.17
# Food                     2468689.43     7920358.03    516504.57
# Publishing               2529760.13     5127914.26    493018.10
# Music                    3128567.25     9109492.74    492955.96
# Sound                    2836324.65     2506746.51    484662.52
# Footwear                 1411266.96     1884957.30    433104.70
# DIY Electronics          1344155.34     1761812.78    415387.36
# Robots                   2671399.97     1988891.59    397134.07
# Camera Equipment         2984776.31     1255936.81    395714.18
# Illustration             2395196.97      870269.81    395226.95
# Accessories              2462515.01     4264788.97    385553.85
# Documentary              3775846.69    10739437.55    373340.77
# Comic Books              1383909.41     1196117.05    367605.21
# Children's Books         2027988.22     3360947.90    355101.43
# Drama                    1159593.18    20084740.49    350715.54
# Graphic Novels           1754303.85     1706950.97    350042.96
# Art Books                1636858.44     2049337.00    346194.37
# Games                    1544553.99     3372070.46    317486.71
# Fabrication Tools        2797972.03      947860.87    312105.06
# ...                             ...            ...          ...
# Typography                 49169.59      422837.41      5977.32
# R&B                        54004.26      425295.24      5485.24
# Printing                   10119.02       72493.59      5004.73
# Punk                       33391.65       37594.84      4583.88
# Conceptual Art             46720.29      283011.20      4481.85
# Blues                      42764.91       76054.57      4459.91
# Journalism                 71438.86      586108.51      4425.86
# Makerspaces                32301.93      337131.66      4235.40
# Farmer's Markets           37604.57      527228.62      4079.52
# Couture                    13608.21      362256.09      3288.54
# Pottery                    46814.84      105480.03      3158.25
# Pet Fashion                54908.29      129507.96      2699.77
# Kids                       92440.81      143572.30      2686.14
# Textiles                   26680.02       91255.77      2477.10
# Embroidery                  8679.04       30857.36      2196.82
# Quilts                     31677.00       62850.00      1860.00
# Animals                    23423.01       32045.70      1854.55
# Bacon                       3636.64      319565.82      1837.28
# Glass                       3540.00       13750.00      1777.00
# Photo                       7059.93      103018.32      1613.25
# Candles                     3306.25       93775.07      1461.57
# Romance                     7271.06      617179.53      1348.14
# Family                      4119.00      975794.27       661.00
# Community Gardens           4042.11      133712.00       612.11
# Translations                1877.77       49577.33       499.70
# Workshops                  12699.67       46078.88       375.00
# Video Art                  15811.05       44907.15       343.41
# Crochet                      825.53       66954.14       164.80
# Residencies                10355.74        9835.04       117.30
# Latin                        637.00       62325.61         0.00
#
# [157 rows x 3 columns]
