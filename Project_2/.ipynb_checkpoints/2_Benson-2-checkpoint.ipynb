# %%
import requests
from bs4 import BeautifulSoup
import dateutil.parser
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import time
import sys

# APIs
import quandl
import coinmarketcap

# %%
sys.executable
# Out:
# '/Users/brianmcmahon/anaconda3/envs/tensorflow1.4/bin/python'

# %%
# Bitcoin prices, called via Quandl API
mydata = pd.read_csv('https://www.quandl.com/api/v3/datasets/BNC3/GWA_BTC.csv?api_key=pvPBMBW8afR_HqVfio9o')
mydata.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2018-01-22  11959.895653  12156.133935  10352.434529  11149.412366
# 1  2018-01-21  13504.939677  13504.939677  11555.969466  11835.516224
# 2  2018-01-20  11959.757141  13653.516571  11959.757141  13479.287914
# 3  2018-01-19  11622.201933  12250.169186  11269.757233  11915.421755
# 4  2018-01-18  11543.993022  12378.199134  11080.069578  11671.307546
#
#           Volume          VWAP          TWAP
# 0  545327.110136  11397.519197  11434.197967
# 1  464489.775175  12326.227544  12327.874370
# 2  440151.270640  13062.680060  13050.789066
# 3  433030.780301  11826.356922  11832.050309
# 4  665369.943093  11792.873670  11807.708648

# %%
y = pd.Series(mydata['Close'])
x = pd.Series(mydata['Date'])

plt.plot(x,y)
plt.title("Bitcoin Closing Price",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.tight_layout()
# plt.savefig('BitcoinPrice.png')
plt.show()

# %%
# Coinmarketcap API; apparently no time series data available 
# http://blockxchain.org/2017/05/29/importing-altcoin-data-with-python-and-the-coinmarketcap-api/
market = coinmarketcap.Market()
coin = market.ticker("ethereum")
coin
# Out:
# [{'24h_volume_usd': '3859330000.0',
#   'available_supply': '97152084.0',
#   'cached': False,
#   'id': 'ethereum',
#   'last_updated': '1516679053',
#   'market_cap_usd': '98137205973.0',
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': '0.68',
#   'percent_change_24h': '-4.4',
#   'percent_change_7d': '-18.45',
#   'price_btc': '0.0924151',
#   'price_usd': '1010.14',
#   'rank': '2',
#   'symbol': 'ETH',
#   'total_supply': '97152084.0'}]

# %%
# Coinmarketcap
url = 'https://coinmarketcap.com/all/views/all/'
response=requests.get(url)
page=response.text
soup=BeautifulSoup(page,"lxml")

tables=soup.find_all("table")

rows=[row for row in tables[0].find_all('tr')]
df = pd.read_html(tables[0].prettify())[0]
df.head()
# Out:
#    #               Name Symbol        Market Cap      Price  \
# 0  1       BTC  Bitcoin    BTC  $185,182,786,995  $11009.40
# 1  2      ETH  Ethereum    ETH   $98,137,205,973   $1010.14
# 2  3        XRP  Ripple    XRP   $52,133,201,438      $1.35
# 3  4  BCH  Bitcoin Cash    BCH   $27,790,645,806   $1641.84
# 4  5       ADA  Cardano    ADA   $14,842,807,123  $0.572483
#
#   Circulating Supply     Volume (24h)   % 1h   % 24h     % 7d
# 0           16820425  $10,767,800,000  1.14%  -5.45%  -17.32%
# 1           97152084   $3,859,330,000  0.68%  -4.40%  -18.45%
# 2  38,739,142,811  *   $2,799,500,000  1.63%  -3.62%  -16.09%
# 3           16926525     $685,204,000  0.87%  -7.87%  -27.96%
# 4  25,927,070,538  *     $519,948,000  0.69%  -5.10%  -22.29%

# %%
# Bitcoin futures
url = 'http://www.cmegroup.com/trading/equity-index/us-index/bitcoin.html'
response=requests.get(url)
page=response.text
soup=BeautifulSoup(page,"lxml")

tables=soup.find_all("table")

rows=[row for row in tables[0].find_all('tr')]
print(rows)
print(tables[0].prettify())
df = pd.read_html(tables[0].prettify())[0]
df = df[:5]
df
# Out:
# [<tr>
# <th class="cmeQuotesMonth" scope="col">Month</th>
# <th class="cmeQuotesCharts" scope="col">Charts</th>
# <th class="cmeQuotesLast" scope="col">Last</th>
# <th class="cmeQuotesChange" scope="col">Change</th>
# <th class="cmeQuotesPriorSettle" scope="col">Prior Settle</th>
# <th class="cmeQuotesOpen" scope="col">Open</th>
# <th class="cmeQuotesHigh" scope="col">High</th>
# <th class="cmeQuotesLow" scope="col">Low</th>
# <th class="cmeQuotesVolume" scope="col">Volume</th>
# <th class="cmeQuotesHiLow" scope="col">Hi / Low Limit</th>
# <th class="cmeQuotesUpdated" scope="col">Updated</th>
# </tr>, <tr>
# <td class="cmeTableFoot" colspan="13">
# <ul class="cmeLegend">
# <li class="cmeLegendItem"><strong>Legend:</strong></li>
# <li class="cmeLegendItem cmeIconListItem cmeOptionsListIcon"><span>Options</span></li>
# <li class="cmeLegendItem cmeIconListItem cmePriceChartListIcon"><span>Price Chart</span></li>
# <li class="cmeSupportingLinks cmeSupportingLinkIcon cmeAboutListIcon"><a href="../../about-quotes.html" rel="popup"><span>About This Report</span></a></li>
# </ul>
# </td>
# </tr>, <tr>
# <th scope="row">
# <span class="cmeNoWrap">JAN 2018</span>
# </th>
# <td>
# <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=JAN_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=F8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
# <span>Show Price Chart</span>
# </a>
# </td>
# <td id="quotesFuturesProductTable1_BTCF8_last"><strong>10885</strong></td>
# <td class="statusOK" id="quotesFuturesProductTable1_BTCF8_change">+530</td>
# <td id="quotesFuturesProductTable1_BTCF8_priorSettle">10355</td>
# <td id="quotesFuturesProductTable1_BTCF8_open">10625</td>
# <td id="quotesFuturesProductTable1_BTCF8_high">10910</td>
# <td id="quotesFuturesProductTable1_BTCF8_low">10560</td>
# <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCF8_volume">110</td>
# <td id="quotesFuturesProductTable1_BTCF8_highLowLimits">11075 / 9635</td>
# <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCF8_updated">21:47:23 CT<br/> 22 Jan 2018</td>
# </tr>, <tr>
# <th scope="row">
# <span class="cmeNoWrap">FEB 2018</span>
# </th>
# <td>
# <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=FEB_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=G8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
# <span>Show Price Chart</span>
# </a>
# </td>
# <td id="quotesFuturesProductTable1_BTCG8_last"><strong>10875</strong></td>
# <td class="statusOK" id="quotesFuturesProductTable1_BTCG8_change">+485</td>
# <td id="quotesFuturesProductTable1_BTCG8_priorSettle">10390</td>
# <td id="quotesFuturesProductTable1_BTCG8_open">10575</td>
# <td id="quotesFuturesProductTable1_BTCG8_high">10960</td>
# <td id="quotesFuturesProductTable1_BTCG8_low">10575</td>
# <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCG8_volume">27</td>
# <td id="quotesFuturesProductTable1_BTCG8_highLowLimits">11145 / 9705</td>
# <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCG8_updated">21:27:37 CT<br/> 22 Jan 2018</td>
# </tr>, <tr>
# <th scope="row">
# <span class="cmeNoWrap">MAR 2018</span>
# </th>
# <td>
# <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=MAR_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=H8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
# <span>Show Price Chart</span>
# </a>
# </td>
# <td id="quotesFuturesProductTable1_BTCH8_last"><strong>10915</strong></td>
# <td class="statusOK" id="quotesFuturesProductTable1_BTCH8_change">+490</td>
# <td id="quotesFuturesProductTable1_BTCH8_priorSettle">10425</td>
# <td id="quotesFuturesProductTable1_BTCH8_open">10725</td>
# <td id="quotesFuturesProductTable1_BTCH8_high">10915</td>
# <td id="quotesFuturesProductTable1_BTCH8_low">10725</td>
# <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCH8_volume">3</td>
# <td id="quotesFuturesProductTable1_BTCH8_highLowLimits">11200 / 9760</td>
# <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCH8_updated">21:28:48 CT<br/> 22 Jan 2018</td>
# </tr>, <tr>
# <th scope="row">
# <span class="cmeNoWrap">APR 2018</span>
# </th>
# <td>
# <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=APR_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=J8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
# <span>Show Price Chart</span>
# </a>
# </td>
# <td id="quotesFuturesProductTable1_BTCJ8_last"><strong>-</strong></td>
# <td class="statusNull" id="quotesFuturesProductTable1_BTCJ8_change">-</td>
# <td id="quotesFuturesProductTable1_BTCJ8_priorSettle">0</td>
# <td id="quotesFuturesProductTable1_BTCJ8_open">-</td>
# <td id="quotesFuturesProductTable1_BTCJ8_high">-</td>
# <td id="quotesFuturesProductTable1_BTCJ8_low">-</td>
# <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCJ8_volume">0</td>
# <td id="quotesFuturesProductTable1_BTCJ8_highLowLimits">-</td>
# <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCJ8_updated">16:45:00 CT<br/> 22 Jan 2018</td>
# </tr>, <tr>
# <th scope="row">
# <span class="cmeNoWrap">JUN 2018</span>
# </th>
# <td>
# <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=JUN_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=M8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
# <span>Show Price Chart</span>
# </a>
# </td>
# <td id="quotesFuturesProductTable1_BTCM8_last"><strong>-</strong></td>
# <td class="statusNull" id="quotesFuturesProductTable1_BTCM8_change">-</td>
# <td id="quotesFuturesProductTable1_BTCM8_priorSettle">10560</td>
# <td id="quotesFuturesProductTable1_BTCM8_open">-</td>
# <td id="quotesFuturesProductTable1_BTCM8_high">-</td>
# <td id="quotesFuturesProductTable1_BTCM8_low">-</td>
# <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCM8_volume">0</td>
# <td id="quotesFuturesProductTable1_BTCM8_highLowLimits">11335 / 9895</td>
# <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCM8_updated">18:31:59 CT<br/> 22 Jan 2018</td>
# </tr>]
# <table border="0" cellpadding="2" cellspacing="0" class="cmeTable cmeQuotesOptionsfalse cmeQuotesGlobextrue cmeQuotesHighLowtrue" id="quotesFuturesProductTable1" summary="Quotes Product Table">
#  <thead>
#   <tr>
#    <th class="cmeQuotesMonth" scope="col">
#     Month
#    </th>
#    <th class="cmeQuotesCharts" scope="col">
#     Charts
#    </th>
#    <th class="cmeQuotesLast" scope="col">
#     Last
#    </th>
#    <th class="cmeQuotesChange" scope="col">
#     Change
#    </th>
#    <th class="cmeQuotesPriorSettle" scope="col">
#     Prior Settle
#    </th>
#    <th class="cmeQuotesOpen" scope="col">
#     Open
#    </th>
#    <th class="cmeQuotesHigh" scope="col">
#     High
#    </th>
#    <th class="cmeQuotesLow" scope="col">
#     Low
#    </th>
#    <th class="cmeQuotesVolume" scope="col">
#     Volume
#    </th>
#    <th class="cmeQuotesHiLow" scope="col">
#     Hi / Low Limit
#    </th>
#    <th class="cmeQuotesUpdated" scope="col">
#     Updated
#    </th>
#   </tr>
#  </thead>
#  <tfoot>
#   <tr>
#    <td class="cmeTableFoot" colspan="13">
#     <ul class="cmeLegend">
#      <li class="cmeLegendItem">
#       <strong>
#        Legend:
#       </strong>
#      </li>
#      <li class="cmeLegendItem cmeIconListItem cmeOptionsListIcon">
#       <span>
#        Options
#       </span>
#      </li>
#      <li class="cmeLegendItem cmeIconListItem cmePriceChartListIcon">
#       <span>
#        Price Chart
#       </span>
#      </li>
#      <li class="cmeSupportingLinks cmeSupportingLinkIcon cmeAboutListIcon">
#       <a href="../../about-quotes.html" rel="popup">
#        <span>
#         About This Report
#        </span>
#       </a>
#      </li>
#     </ul>
#    </td>
#   </tr>
#  </tfoot>
#  <tbody>
#   <tr>
#    <th scope="row">
#     <span class="cmeNoWrap">
#      JAN 2018
#     </span>
#    </th>
#    <td>
#     <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=JAN_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=F8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
#      <span>
#       Show Price Chart
#      </span>
#     </a>
#    </td>
#    <td id="quotesFuturesProductTable1_BTCF8_last">
#     <strong>
#      10885
#     </strong>
#    </td>
#    <td class="statusOK" id="quotesFuturesProductTable1_BTCF8_change">
#     +530
#    </td>
#    <td id="quotesFuturesProductTable1_BTCF8_priorSettle">
#     10355
#    </td>
#    <td id="quotesFuturesProductTable1_BTCF8_open">
#     10625
#    </td>
#    <td id="quotesFuturesProductTable1_BTCF8_high">
#     10910
#    </td>
#    <td id="quotesFuturesProductTable1_BTCF8_low">
#     10560
#    </td>
#    <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCF8_volume">
#     110
#    </td>
#    <td id="quotesFuturesProductTable1_BTCF8_highLowLimits">
#     11075 / 9635
#    </td>
#    <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCF8_updated">
#     21:47:23 CT
#     <br/>
#     22 Jan 2018
#    </td>
#   </tr>
#   <tr>
#    <th scope="row">
#     <span class="cmeNoWrap">
#      FEB 2018
#     </span>
#    </th>
#    <td>
#     <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=FEB_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=G8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
#      <span>
#       Show Price Chart
#      </span>
#     </a>
#    </td>
#    <td id="quotesFuturesProductTable1_BTCG8_last">
#     <strong>
#      10875
#     </strong>
#    </td>
#    <td class="statusOK" id="quotesFuturesProductTable1_BTCG8_change">
#     +485
#    </td>
#    <td id="quotesFuturesProductTable1_BTCG8_priorSettle">
#     10390
#    </td>
#    <td id="quotesFuturesProductTable1_BTCG8_open">
#     10575
#    </td>
#    <td id="quotesFuturesProductTable1_BTCG8_high">
#     10960
#    </td>
#    <td id="quotesFuturesProductTable1_BTCG8_low">
#     10575
#    </td>
#    <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCG8_volume">
#     27
#    </td>
#    <td id="quotesFuturesProductTable1_BTCG8_highLowLimits">
#     11145 / 9705
#    </td>
#    <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCG8_updated">
#     21:27:37 CT
#     <br/>
#     22 Jan 2018
#    </td>
#   </tr>
#   <tr>
#    <th scope="row">
#     <span class="cmeNoWrap">
#      MAR 2018
#     </span>
#    </th>
#    <td>
#     <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=MAR_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=H8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
#      <span>
#       Show Price Chart
#      </span>
#     </a>
#    </td>
#    <td id="quotesFuturesProductTable1_BTCH8_last">
#     <strong>
#      10915
#     </strong>
#    </td>
#    <td class="statusOK" id="quotesFuturesProductTable1_BTCH8_change">
#     +490
#    </td>
#    <td id="quotesFuturesProductTable1_BTCH8_priorSettle">
#     10425
#    </td>
#    <td id="quotesFuturesProductTable1_BTCH8_open">
#     10725
#    </td>
#    <td id="quotesFuturesProductTable1_BTCH8_high">
#     10915
#    </td>
#    <td id="quotesFuturesProductTable1_BTCH8_low">
#     10725
#    </td>
#    <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCH8_volume">
#     3
#    </td>
#    <td id="quotesFuturesProductTable1_BTCH8_highLowLimits">
#     11200 / 9760
#    </td>
#    <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCH8_updated">
#     21:28:48 CT
#     <br/>
#     22 Jan 2018
#    </td>
#   </tr>
#   <tr>
#    <th scope="row">
#     <span class="cmeNoWrap">
#      APR 2018
#     </span>
#    </th>
#    <td>
#     <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=APR_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=J8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
#      <span>
#       Show Price Chart
#      </span>
#     </a>
#    </td>
#    <td id="quotesFuturesProductTable1_BTCJ8_last">
#     <strong>
#      -
#     </strong>
#    </td>
#    <td class="statusNull" id="quotesFuturesProductTable1_BTCJ8_change">
#     -
#    </td>
#    <td id="quotesFuturesProductTable1_BTCJ8_priorSettle">
#     0
#    </td>
#    <td id="quotesFuturesProductTable1_BTCJ8_open">
#     -
#    </td>
#    <td id="quotesFuturesProductTable1_BTCJ8_high">
#     -
#    </td>
#    <td id="quotesFuturesProductTable1_BTCJ8_low">
#     -
#    </td>
#    <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCJ8_volume">
#     0
#    </td>
#    <td id="quotesFuturesProductTable1_BTCJ8_highLowLimits">
#     -
#    </td>
#    <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCJ8_updated">
#     16:45:00 CT
#     <br/>
#     22 Jan 2018
#    </td>
#   </tr>
#   <tr>
#    <th scope="row">
#     <span class="cmeNoWrap">
#      JUN 2018
#     </span>
#    </th>
#    <td>
#     <a class="cmeIconListItem cmePriceChartImageIcon" href="/apps/cmegroup/widgets/productLibs/esignal-charts.html?code=BTC&amp;title=JUN_2018_Bitcoin_&amp;type=p&amp;venue=0&amp;monthYear=M8&amp;year=2018&amp;exchangeCode=XCME" rel="priceChart, nofollow">
#      <span>
#       Show Price Chart
#      </span>
#     </a>
#    </td>
#    <td id="quotesFuturesProductTable1_BTCM8_last">
#     <strong>
#      -
#     </strong>
#    </td>
#    <td class="statusNull" id="quotesFuturesProductTable1_BTCM8_change">
#     -
#    </td>
#    <td id="quotesFuturesProductTable1_BTCM8_priorSettle">
#     10560
#    </td>
#    <td id="quotesFuturesProductTable1_BTCM8_open">
#     -
#    </td>
#    <td id="quotesFuturesProductTable1_BTCM8_high">
#     -
#    </td>
#    <td id="quotesFuturesProductTable1_BTCM8_low">
#     -
#    </td>
#    <td class="cmeTableRight" id="quotesFuturesProductTable1_BTCM8_volume">
#     0
#    </td>
#    <td id="quotesFuturesProductTable1_BTCM8_highLowLimits">
#     11335 / 9895
#    </td>
#    <td class="cmeUpdatedField" id="quotesFuturesProductTable1_BTCM8_updated">
#     18:31:59 CT
#     <br/>
#     22 Jan 2018
#    </td>
#   </tr>
#  </tbody>
# </table>
#       Month            Charts   Last Change  Prior Settle   Open   High  \
# 0  JAN 2018  Show Price Chart  10885   +530       10355.0  10625  10910
# 1  FEB 2018  Show Price Chart  10875   +485       10390.0  10575  10960
# 2  MAR 2018  Show Price Chart  10915   +490       10425.0  10725  10915
# 3  APR 2018  Show Price Chart      -      -           0.0      -      -
# 4  JUN 2018  Show Price Chart      -      -       10560.0      -      -
#
#      Low  Volume Hi / Low Limit                   Updated
# 0  10560   110.0   11075 / 9635  21:47:23 CT  22 Jan 2018
# 1  10575    27.0   11145 / 9705  21:27:37 CT  22 Jan 2018
# 2  10725     3.0   11200 / 9760  21:28:48 CT  22 Jan 2018
# 3      -     0.0              -  16:45:00 CT  22 Jan 2018
# 4      -     0.0   11335 / 9895  18:31:59 CT  22 Jan 2018
