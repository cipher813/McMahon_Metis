# %% [markdown]
# ## WTWY NYC Street Team Deployment Analysis
# Emily Geller and Brian McMahon
#
# ### Executive Summary / Problem Statement
# - Tasked with optimizing WTWY street team placement for raising awareness of upcoming gala
# - Utilized NYC MTA and demographic data to perform analysis on areas with high traffic and favorable demographics
# - Findings identified major traffic hubs where placement of street teams would be optimal based on surrounding population
# - Recommended stations for mobilizing street teams include: Penn Station, Herald Square, Grand Central, Times Square and 23rd Street

# %% [markdown]
# ### Import Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# https://data.ny.gov/Transportation/Turnstile-Usage-Data-2016/ekwu-khcy
# https://data.ny.gov/api/views/ekwu-khcy/rows.csv?accessType=DOWNLOAD
data = pd.read_csv('Turnstile_Usage_Data__2016.csv',dtype={'C/A': str,'Unit':str,'SCP':str,'Station':str,'Line Name':str, 'Division':str,'Date': object, 'Time':object,'Description':str,'Entries':int,'Exits':int})
data = pd.DataFrame(data) # change to pandas dataframe
# parse spaces from columns  
data=data.rename(columns = {'Exits                                                     ':'Exits'})

# %%
# remove first few columns of turnstile data; not used in our analysis
data = data.iloc[:,3:]
data.head()
# Out:
#   Station Line Name Division        Date      Time Description  Entries  \
# 0   59 ST    NQR456      BMT  03/04/2016  23:00:00     REGULAR  5572864
# 1   59 ST    NQR456      BMT  03/04/2016  19:00:00     REGULAR  5572521
# 2   59 ST    NQR456      BMT  03/04/2016  15:00:00     REGULAR  5571587
# 3   59 ST    NQR456      BMT  03/04/2016  11:00:00     REGULAR  5571313
# 4   59 ST    NQR456      BMT  03/04/2016  08:10:05     REGULAR  5571173
#
#      Exits
# 0  1881239
# 1  1881206
# 2  1881113
# 3  1881031
# 4  1880736

# %% [markdown]
# ### Process Data

# %%
# Data presented as cumulative; add columns to track the increment
# Add Traffic_Tot column as sum of Entry and Exit to represent activity
data['Entry_Inc'] = abs(data.Entries.diff())
data['Exits_Inc'] = abs(data.Exits.diff())
data['Traffic_Tot'] = np.add(data.Entry_Inc, data.Exits_Inc)
data.head()
# Out:
#   Station Line Name Division        Date      Time Description  Entries  \
# 0   59 ST    NQR456      BMT  03/04/2016  23:00:00     REGULAR  5572864
# 1   59 ST    NQR456      BMT  03/04/2016  19:00:00     REGULAR  5572521
# 2   59 ST    NQR456      BMT  03/04/2016  15:00:00     REGULAR  5571587
# 3   59 ST    NQR456      BMT  03/04/2016  11:00:00     REGULAR  5571313
# 4   59 ST    NQR456      BMT  03/04/2016  08:10:05     REGULAR  5571173
#
#      Exits  Entry_Inc  Exits_Inc  Traffic_Tot
# 0  1881239        NaN        NaN          NaN
# 1  1881206      343.0       33.0        376.0
# 2  1881113      934.0       93.0       1027.0
# 3  1881031      274.0       82.0        356.0
# 4  1880736      140.0      295.0        435.0

# %%
# filter outliers above specified quantile
quant_filt = 0.99
q = data["Entry_Inc"].quantile(quant_filt)
data = data[data["Entry_Inc"] < q]

r = data["Exits_Inc"].quantile(quant_filt)
data = data[data["Exits_Inc"] < r]

s = data["Traffic_Tot"].quantile(quant_filt)
data = data[data["Traffic_Tot"] < s]

data = data.dropna() # apparently no issues with NaN cells; running as best practice

data.head()
# Out:
#   Station Line Name Division        Date      Time Description  Entries  \
# 1   59 ST    NQR456      BMT  03/04/2016  19:00:00     REGULAR  5572521
# 2   59 ST    NQR456      BMT  03/04/2016  15:00:00     REGULAR  5571587
# 3   59 ST    NQR456      BMT  03/04/2016  11:00:00     REGULAR  5571313
# 4   59 ST    NQR456      BMT  03/04/2016  08:10:05     REGULAR  5571173
# 5   59 ST    NQR456      BMT  03/04/2016  07:00:00     REGULAR  5571136
#
#      Exits  Entry_Inc  Exits_Inc  Traffic_Tot
# 1  1881206      343.0       33.0        376.0
# 2  1881113      934.0       93.0       1027.0
# 3  1881031      274.0       82.0        356.0
# 4  1880736      140.0      295.0        435.0
# 5  1880657       37.0       79.0        116.0

# %% [markdown]
# ### Sort Data
# Data is sorted by Station.

# %%
data_stn = data.groupby(["Station"]).sum() # sort by station
data_stn['Station_ID'] = data_stn.index # Make Station_ID a non-index column
data_stn = data_stn.sort_values(['Traffic_Tot'], ascending=[False]) # Sort stations by traffic
data_stn['Idx'] = np.arange(data_stn.shape[0]) # add enumerated column
data_stn = data_stn.set_index('Idx') # assign enumerated column as index column
data_stn.head()
# Out:
#             Entries           Exits   Entry_Inc   Exits_Inc  Traffic_Tot  \
# Idx
# 0     6688304157199   3630511989854  43389327.0  35722750.0   79112077.0
# 1    12665339112269  11696989712585  31416768.0  23977529.0   55394297.0
# 2     5847951627430   6098512500597  27860423.0  24614007.0   52474430.0
# 3    11539236191101   9178257398340  25838571.0  23245722.0   49084293.0
# 4     7901555330882   2052315189136  25151182.0  22764739.0   47915921.0
#
#           Station_ID
# Idx
# 0     34 ST-PENN STA
# 1              23 ST
# 2    34 ST-HERALD SQ
# 3     TIMES SQ-42 ST
# 4    GRD CNTRL-42 ST

# %% [markdown]
# ## Prep Data for Charting

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
data_stn = data_stn.iloc[:20,:] # limit to 20 most active stations
data_stn.head()
# Out:
#             Entries           Exits   Entry_Inc   Exits_Inc  Traffic_Tot  \
# Idx
# 0     6688304157199   3630511989854  43389327.0  35722750.0   79112077.0
# 1    12665339112269  11696989712585  31416768.0  23977529.0   55394297.0
# 2     5847951627430   6098512500597  27860423.0  24614007.0   52474430.0
# 3    11539236191101   9178257398340  25838571.0  23245722.0   49084293.0
# 4     7901555330882   2052315189136  25151182.0  22764739.0   47915921.0
#
#           Station_ID
# Idx
# 0     34 ST-PENN STA
# 1              23 ST
# 2    34 ST-HERALD SQ
# 3     TIMES SQ-42 ST
# 4    GRD CNTRL-42 ST

# %%
# verify results: check http://web.mta.info/nyct/facts/ffsubway.htm
ax = sns.barplot(x="Traffic_Tot", y='Station_ID', data=data_stn)

plt.xlabel('Traffic', fontsize=12)
plt.ylabel('Station', fontsize=12)
plt.tight_layout()
plt.savefig('charts/Top20.png')
plt.show()

# %%
y = pd.Series(data_stn['Station_ID'])
x = pd.Series(data_stn['Traffic_Tot'])

plt.rcdefaults()
fig, ax = plt.subplots()

ax.barh(y, x, align='center',
        color='green', ecolor='black')
ax.set_yticks(y)
ax.set_yticklabels(y)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Traffic')
ax.set_ylabel('Station')
ax.set_title('Top NYC Subway Stations by Traffic')

plt.show()

# %% [markdown]
# ### System Traffic by Date

# %%
data_date = data.groupby(["Date"]).sum() # sort by station and date
data_date.reset_index(inplace=True) # remove Station and Date columns from Index
data_date['Date'] = pd.to_datetime(data_date['Date']) # change Date dtype to datetime
data_date.head()
# Out:
#         Date       Entries         Exits  Entry_Inc  Exits_Inc  Traffic_Tot
# 0 2016-01-02  907632125960  737352069186  3169594.0  2505691.0    5675285.0
# 1 2016-01-03  910489047955  739150691227  2524603.0  2013048.0    4537651.0
# 2 2016-01-04  889345474041  720704205148  5161723.0  3780033.0    8941756.0
# 3 2016-01-05  991793599669  799768119501  5194901.0  3819590.0    9014491.0
# 4 2016-01-06  909905816742  724269122184  5404410.0  3948491.0    9352901.0

# %%
y = pd.Series(data_date['Traffic_Tot'])
x = pd.Series(data_date['Date'])

plt.plot(x,y)
plt.title("System Seasonal Traffic",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic', fontsize=12)
plt.tight_layout()
plt.savefig('charts/SystemTraffic.png')
plt.show()

# %% [markdown]
# ### Top Station Activity: Penn Station 34th Street

# %%
data_stndate = data.groupby([ "Station", "Date"]).sum() # sort by station and date
data_stndate.reset_index(inplace=True) # remove Station and Date columns from Index
data_stndate['Date'] = pd.to_datetime(data_stndate['Date']) # change Date dtype to datetime
data_stndate.head()
# Out:
#   Station       Date     Entries       Exits  Entry_Inc  Exits_Inc  \
# 0    1 AV 2016-01-02  8446763163  8816182716    16816.0    18856.0
# 1    1 AV 2016-01-03  8446860211  8816289298    12942.0    13808.0
# 2    1 AV 2016-01-04  8360994609  8720116887    16601.0    16539.0
# 3    1 AV 2016-01-05  8306184305  8684658647    15213.0    16666.0
# 4    1 AV 2016-01-06  8306899059  8693492544    16506.0    18685.0
#
#    Traffic_Tot
# 0      35672.0
# 1      26750.0
# 2      33140.0
# 3      31879.0
# 4      35191.0

# %%
data_Penn = data_stndate[data_stndate['Station'] == '34 ST-PENN STA'] # filter to date by specific station

y = pd.Series(data_Penn['Traffic_Tot'])
x = pd.Series(data_Penn['Date'])

plt.plot(x,y)
plt.title("Top Station Activity: Penn Station 34th Street",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic', fontsize=12)
plt.tight_layout()
plt.savefig('charts/Penn.png')
plt.show()

# %% [markdown]
# ### Top Station Activity: 23rd St

# %%
data_23ST = data_stndate[data_stndate['Station'] == '23 ST']

y = pd.Series(data_23ST['Traffic_Tot'])
x = pd.Series(data_23ST['Date'])

plt.plot(x,y)
plt.title("Top Station Activity: 23rd Street",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic', fontsize=12)
plt.tight_layout()
plt.savefig('charts/23RD.png')
plt.show()

# %% [markdown]
# ### Top Station Activity: Herald Square 34th Street

# %%
data_34ST = data_stndate[data_stndate['Station'] == '34 ST-HERALD SQ']

y = pd.Series(data_34ST['Traffic_Tot'])
x = pd.Series(data_34ST['Date'])

plt.plot(x,y)
plt.title("Top Station Activity: 34th Street Herald Square",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic', fontsize=12)
plt.tight_layout()
plt.savefig('charts/34TH.png')
plt.show()

# %% [markdown]
# ### Top Station Activity: Times Square 42nd St

# %%
data_TSQ = data_stndate[data_stndate['Station'] == 'TIMES SQ-42 ST']

y = pd.Series(data_TSQ['Traffic_Tot'])
x = pd.Series(data_TSQ['Date'])

plt.plot(x,y)
plt.title("Top Station Activity: Times Square 42nd Street",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic', fontsize=12)
plt.tight_layout()
plt.savefig('charts/TSQ.png')
plt.show()

# %% [markdown]
# ### Top Station Activity: Grand Central 42nd St

# %%
data_GRD = data_stndate[data_stndate['Station'] == 'GRD CNTRL-42 ST']

y = pd.Series(data_GRD['Traffic_Tot'])
x = pd.Series(data_GRD['Date'])

plt.plot(x,y)
plt.title("Top Station Activity: Grand Central 42nd Street",fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Traffic', fontsize=12)
plt.tight_layout()
plt.savefig('charts/GRD.png')
plt.show()

# %% [markdown]
# ### Top Station Activity: 72nd St (#20, for comparison purposes)

# %%
data_72ST = data_stndate[data_stndate['Station'] == '72 ST']
y = pd.Series(data_72ST['Traffic_Tot'])
x = pd.Series(data_72ST['Date'])

plt.plot(x,y)
plt.title("Top Station Activity: 72nd Street")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Demographics Analysis

# %% [markdown]
# Data sourced from : https://www.kaggle.com/muonneutrino/mapping-new-york-city-census-data/data
#
# census_block_loc.csv was orginally sourced from: https://factfinder.census.gov/faces/nav/jsf/pages/index.xhtml
#
# total population, racial/ethnic demographic information, employment and commuting characteristics, and more are contained here
# nyc_census_tracts.csv was originally sourced from: https://www.fcc.gov/general/census-block-conversions-api
#
# This file contains the coordinates and associated census block codes along with the state and county names

# %%
blocks_map = pd.read_csv('census_block_loc.csv')
census = pd.read_csv('nyc_census_tracts.csv', index_col=0)

# %%
blocks_map.head()
# Out:
#    Latitude  Longitude        BlockCode     County State
# 0     40.48 -74.280000  340230076002012  Middlesex    NJ
# 1     40.48 -74.276834  340230076005000  Middlesex    NJ
# 2     40.48 -74.273668  340230076003018  Middlesex    NJ
# 3     40.48 -74.270503  340230076003004  Middlesex    NJ
# 4     40.48 -74.267337  340230074021000  Middlesex    NJ

# %%
census.head()
# Out:
#             County Borough  TotalPop   Men  Women  Hispanic  White  Black  \
# CensusTract
# 36005000100  Bronx   Bronx      7703  7133    570      29.9    6.1   60.9
# 36005000200  Bronx   Bronx      5403  2659   2744      75.8    2.3   16.0
# 36005000400  Bronx   Bronx      5915  2896   3019      62.7    3.6   30.7
# 36005001600  Bronx   Bronx      5879  2558   3321      65.1    1.6   32.4
# 36005001900  Bronx   Bronx      2591  1206   1385      55.4    9.0   29.0
#
#              Native  Asian      ...       Walk  OtherTransp  WorkAtHome  \
# CensusTract                     ...
# 36005000100     0.2    1.6      ...        NaN          NaN         NaN
# 36005000200     0.0    4.2      ...        2.9          0.0         0.0
# 36005000400     0.0    0.3      ...        1.4          0.5         2.1
# 36005001600     0.0    0.0      ...        8.6          1.6         1.7
# 36005001900     0.0    2.1      ...        3.0          2.4         6.2
#
#              MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# CensusTract
# 36005000100          NaN         0          NaN         NaN           NaN
# 36005000200         43.0      2308         80.8        16.2           2.9
# 36005000400         45.0      2675         71.7        25.3           2.5
# 36005001600         38.8      2120         75.0        21.3           3.8
# 36005001900         45.4      1083         76.8        15.5           7.7
#
#              FamilyWork  Unemployment
# CensusTract
# 36005000100         NaN           NaN
# 36005000200         0.0           7.7
# 36005000400         0.6           9.5
# 36005001600         0.0           8.7
# 36005001900         0.0          19.2
#
# [5 rows x 35 columns]

# %%
census.County.unique()
# Out:
# array(['Bronx', 'Kings', 'New York', 'Queens', 'Richmond'], dtype=object)

# %% [markdown]
# Combine both tables on Block Code. (Tract is the first 11 digits BlockCode)

# %%
blocks_map = blocks_map[blocks_map.County.isin(['Bronx','Kings','New York','Queens', 'Richmond'])]
blocks_map['Tract'] = blocks_map.BlockCode // 10000
blocks_map['Tract'] = blocks_map.BlockCode // 10000
blocks_map = blocks_map.merge(census,how='left',right_index=True,left_on='Tract')

blocks_map.describe()
# Out:
#            Latitude     Longitude     BlockCode         Tract      TotalPop  \
# count  18053.000000  18053.000000  1.805300e+04  1.805300e+04  18052.000000
# mean      40.663945    -73.938191  3.606427e+14  3.606427e+10   2911.090682
# std        0.108223      0.130486  2.647918e+11  2.647918e+07   2963.959357
# min       40.480000    -74.257839  3.600500e+14  3.600500e+10      0.000000
# 25%       40.572714    -74.020402  3.604707e+14  3.604707e+10      0.000000
# 50%       40.645075    -73.915930  3.608106e+14  3.608106e+10   2627.000000
# 75%       40.746834    -73.836784  3.608199e+14  3.608199e+10   4586.000000
# max       40.916432    -73.700653  3.608599e+14  3.608599e+10  28926.000000
#
#                 Men         Women      Hispanic         White         Black  \
# count  18052.000000  18052.000000  12999.000000  12999.000000  12999.000000
# mean    1411.314591   1499.776091     23.607047     42.815132     19.688084
# std     1433.417834   1570.619628     21.308169     33.096275     27.271547
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      7.700000      8.300000      0.900000
# 50%     1318.000000   1346.000000     16.600000     44.600000      5.100000
# 75%     2214.000000   2382.000000     32.100000     71.200000     28.300000
# max    13460.000000  15466.000000    100.000000    100.000000    100.000000
#
#            ...               Walk   OtherTransp    WorkAtHome   MeanCommute  \
# count      ...       12777.000000  12777.000000  12777.000000  11864.000000
# mean       ...           6.684503      1.955193      4.175033     41.353911
# std        ...           9.074818      3.704082      7.743335      6.959058
# min        ...           0.000000      0.000000      0.000000     15.200000
# 25%        ...           1.200000      0.000000      1.200000     37.400000
# 50%        ...           4.000000      1.000000      2.500000     41.500000
# 75%        ...           8.200000      2.300000      4.700000     45.700000
# max        ...         100.000000     55.600000    100.000000     70.500000
#
#            Employed   PrivateWork    PublicWork  SelfEmployed    FamilyWork  \
# count  18052.000000  12777.000000  12777.000000  12777.000000  12777.000000
# mean    1326.003601     78.087822     16.350239      5.449339      0.114229
# std     1413.643704      8.654013      8.628300      4.719631      0.405476
# min        0.000000     38.600000      0.000000      0.000000      0.000000
# 25%        0.000000     73.600000     10.500000      2.800000      0.000000
# 50%     1165.000000     78.200000     15.900000      4.900000      0.000000
# 75%     2077.000000     83.200000     21.300000      7.300000      0.000000
# max    12780.000000    100.000000     53.700000     61.400000      3.900000
#
#        Unemployment
# count  12830.000000
# mean       8.783001
# std        8.350183
# min        0.000000
# 25%        5.000000
# 50%        7.500000
# 75%       11.000000
# max      100.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ### Plot Demographics Data

# %% [markdown]
# The following code was found here: https://www.kaggle.com/muonneutrino/mapping-new-york-city-census-data/notebook.
# We use this to map demographic information.

# %%
def convert_to_2d(lats,lons,values):
    latmin = 40.48
    lonmin = -74.28
    latmax = 40.93
    lonmax = -73.65
    lon_vals = np.mgrid[lonmin:lonmax:200j]
    lat_vals = np.mgrid[latmin:latmax:200j]
    map_values = np.zeros([200,200])
    dlat = lat_vals[1] - lat_vals[0]
    dlon = lon_vals[1] - lon_vals[0]
    for lat,lon,value in zip(lats,lons,values):
        lat_idx = int(np.rint((lat - latmin) / dlat))
        lon_idx = int(np.rint((lon-lonmin) / dlon ))        
        if not np.isnan(value):
            map_values[lon_idx,lat_idx] = value
    return lat_vals,lon_vals,map_values

# %%
def make_plot(blocks, data_values,title='',colors='Greens'):
    lat_vals,lon_vals,values = convert_to_2d(blocks.Latitude,blocks.Longitude,data_values)
    fig, ax = plt.subplots(figsize = [12,12])
    limits = np.min(lon_vals),np.max(lon_vals),np.min(lat_vals),np.max(lat_vals)
    
    im = ax.imshow(values.T,origin='lower',cmap=colors,extent=limits, zorder = 1)
    ax.autoscale(False)
    plt.xlabel('Longitude [degrees]')
    plt.ylabel('Latitude [degrees]')
    plt.title(title)
    plt.colorbar(im,fraction=0.035, pad=0.04)
    plt.show()

# %% [markdown]
# #### Median Household Income by Lat/Long

# %%
make_plot(blocks_map, blocks_map.Income,colors='plasma',title='Median Household Income ($)')

# %% [markdown]
# #### Percentage of Population Taking Public Transportation to Work

# %%
make_plot(blocks_map, blocks_map.Transit,colors='plasma',title='Percentage Taking Public Transportation to Work')

# %% [markdown]
# #### Female Population Concentrations by Lat/Long

# %%
make_plot(blocks_map, blocks_map.Women,colors='plasma',title='Female Population')

# %% [markdown]
# ### Further Analysis
# Limit the data included in the dataframe to only include those demographics that we are interested in (number of Women, Total Population, Percentage of Population taking Public Transportatin and Median Household Income).

# %%
filtered_blocks = blocks_map[['Latitude', 'Longitude', 'BlockCode', 'County_x', 'Women', 'TotalPop', 'Transit', 'Income']]

# %% [markdown]
# Create a new column holding the percentage of the population who are female.

# %%
filtered_blocks['women_pop_perc'] = np.divide(np.array(filtered_blocks['Women'], int),np.array(filtered_blocks['TotalPop'],int))
# Out:
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
filtered_blocks.describe()
# Out:
#            Latitude     Longitude     BlockCode         Women      TotalPop  \
# count  18053.000000  18053.000000  1.805300e+04  18052.000000  18052.000000
# mean      40.663945    -73.938191  3.606427e+14   1499.776091   2911.090682
# std        0.108223      0.130486  2.647918e+11   1570.619628   2963.959357
# min       40.480000    -74.257839  3.600500e+14      0.000000      0.000000
# 25%       40.572714    -74.020402  3.604707e+14      0.000000      0.000000
# 50%       40.645075    -73.915930  3.608106e+14   1346.000000   2627.000000
# 75%       40.746834    -73.836784  3.608199e+14   2382.000000   4586.000000
# max       40.916432    -73.700653  3.608599e+14  15466.000000  28926.000000
#
#             Transit         Income  women_pop_perc
# count  12777.000000   11947.000000    13000.000000
# mean      44.844486   66464.034737        0.513941
# std       20.761257   26952.609291        0.101982
# min        0.000000    9829.000000        0.000000
# 25%       27.200000   45991.000000        0.489385
# 50%       44.200000   66250.000000        0.515745
# 75%       62.200000   84559.000000        0.544983
# max      100.000000  244375.000000        1.000000

# %% [markdown]
# Top 10 Stations

# %%
top_10 = data_stn.head(10)
top_10
# Out:
#             Entries           Exits   Entry_Inc   Exits_Inc  Traffic_Tot  \
# Idx
# 0     6688304157199   3630511989854  43389327.0  35722750.0   79112077.0
# 1    12665339112269  11696989712585  31416768.0  23977529.0   55394297.0
# 2     5847951627430   6098512500597  27860423.0  24614007.0   52474430.0
# 3    11539236191101   9178257398340  25838571.0  23245722.0   49084293.0
# 4     7901555330882   2052315189136  25151182.0  22764739.0   47915921.0
# 5     4717863457538   5054584156147  27976770.0  19524148.0   47500918.0
# 6    15015687906877  12431372573038  27764853.0  18504967.0   46269820.0
# 7     8246409562531   8555427124598  24449068.0  19832307.0   44281375.0
# 8     2393981063586    758394530095  22754780.0  21055089.0   43809869.0
# 9    12190325250181   6696232532269  23490571.0  17785738.0   41276309.0
#
#           Station_ID
# Idx
# 0     34 ST-PENN STA
# 1              23 ST
# 2    34 ST-HERALD SQ
# 3     TIMES SQ-42 ST
# 4    GRD CNTRL-42 ST
# 5              86 ST
# 6    42 ST-PORT AUTH
# 7          FULTON ST
# 8     14 ST-UNION SQ
# 9             125 ST

# %%
top_10['Latitude'] = [40.7520, 40.7427, 40.7496, 40.7553, 40.7527, 40.4640, 40.7572, 40.7094, 40.4429, 40.8049]
top_10['Longitude'] = [-73.9933, -73.9926, -73.9877, -73.9869, -73.9772, -73.5706, -73.9898, -74.0083, -73.5914, -73.9385]
# Out:
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
top_10
# Out:
#             Entries           Exits   Entry_Inc   Exits_Inc  Traffic_Tot  \
# Idx
# 0     6688304157199   3630511989854  43389327.0  35722750.0   79112077.0
# 1    12665339112269  11696989712585  31416768.0  23977529.0   55394297.0
# 2     5847951627430   6098512500597  27860423.0  24614007.0   52474430.0
# 3    11539236191101   9178257398340  25838571.0  23245722.0   49084293.0
# 4     7901555330882   2052315189136  25151182.0  22764739.0   47915921.0
# 5     4717863457538   5054584156147  27976770.0  19524148.0   47500918.0
# 6    15015687906877  12431372573038  27764853.0  18504967.0   46269820.0
# 7     8246409562531   8555427124598  24449068.0  19832307.0   44281375.0
# 8     2393981063586    758394530095  22754780.0  21055089.0   43809869.0
# 9    12190325250181   6696232532269  23490571.0  17785738.0   41276309.0
#
#           Station_ID  Latitude  Longitude
# Idx
# 0     34 ST-PENN STA   40.7520   -73.9933
# 1              23 ST   40.7427   -73.9926
# 2    34 ST-HERALD SQ   40.7496   -73.9877
# 3     TIMES SQ-42 ST   40.7553   -73.9869
# 4    GRD CNTRL-42 ST   40.7527   -73.9772
# 5              86 ST   40.4640   -73.5706
# 6    42 ST-PORT AUTH   40.7572   -73.9898
# 7          FULTON ST   40.7094   -74.0083
# 8     14 ST-UNION SQ   40.4429   -73.5914
# 9             125 ST   40.8049   -73.9385

# %% [markdown]
# ### Demographics in half square mile around 34 - Penn St Station
# 40.7520	-73.9933

# %%
filtered_blocks[((filtered_blocks['Latitude'] < 40.753) & (filtered_blocks['Latitude'] > 40.751))&((filtered_blocks['Longitude']>-73.995)&(filtered_blocks['Longitude']<-73.991))]#.describe()
# Out:
#         Latitude  Longitude        BlockCode  County_x  Women  TotalPop  \
# 22487  40.751357  -73.99191  360610101001002  New York  501.0    1259.0
#
#        Transit    Income  women_pop_perc
# 22487     41.1  159821.0        0.397935

# %% [markdown]
# ### Demographics in half square around 23 St Station
# 40.7427	-73.9926

# %%
filtered_blocks[((filtered_blocks['Latitude'] < 40.755) & (filtered_blocks['Latitude'] > 40.753))&((filtered_blocks['Longitude']>-73.993)&(filtered_blocks['Longitude']<-73.991))]#.describe()
# Out:
#         Latitude  Longitude        BlockCode  County_x  Women  TotalPop  \
# 22687  40.753618  -73.99191  360610109001003  New York  113.0     186.0
#
#        Transit    Income  women_pop_perc
# 22687     48.4  135750.0        0.607527

# %% [markdown]
# ## Demographics in half square mile around 34 St - Herald Sq
# 40.7496	-73.9877

# %%
filtered_blocks[((filtered_blocks['Latitude'] < 40.750) & (filtered_blocks['Latitude'] > 40.747))&((filtered_blocks['Longitude']>-73.986)&(filtered_blocks['Longitude']<-73.984))]
# Out:
#         Latitude  Longitude        BlockCode  County_x   Women  TotalPop  \
# 22289  40.749095 -73.985578  360610076001000  New York  1069.0    1912.0
#
#        Transit    Income  women_pop_perc
# 22289     36.5  103264.0          0.5591

# %% [markdown]
# ## Demographics in half square mile around Grand Central 42nd St
# 40.7527	-73.9772

# %%
filtered_blocks[((filtered_blocks['Latitude'] < 40.754) & (filtered_blocks['Latitude'] > 40.752))&((filtered_blocks['Longitude']>-73.977)&(filtered_blocks['Longitude']<-73.976))]
# Out:
#         Latitude  Longitude        BlockCode  County_x  Women  TotalPop  \
# 22692  40.753618  -73.97608  360610092001008  New York  895.0    1717.0
#
#        Transit    Income  women_pop_perc
# 22692     37.2  122379.0        0.521258

# %% [markdown]
# ## Demographic in half square mile around Times Sq 42nd St
# 40.7553	-73.9869

# %%
filtered_blocks[((filtered_blocks['Latitude'] < 40.756) & (filtered_blocks['Latitude'] > 40.754))&((filtered_blocks['Longitude']>-73.989)&(filtered_blocks['Longitude']<-73.986))]
# Out:
#         Latitude  Longitude        BlockCode  County_x  Women  TotalPop  \
# 22888  40.755879 -73.988744  360610113001003  New York   30.0     126.0
#
#        Transit   Income  women_pop_perc
# 22888     44.4  82361.0        0.238095

# %%
make_plot(filtered_blocks, filtered_blocks.women_pop_perc,colors='plasma',title='Female Population')
