# %%
# Find subway data
# Deliverables:
# 
# high traffic, higher income, other key demographics?

# %%
import pandas as pd
import numpy as np

# %%
# entrances = pd.read_csv('http://web.mta.info/developers/data/nyct/subway/StationEntrances.csv')
# print(entrances.shape)
# Out:
# (1866, 30)

# %%
# turnstile = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_180113.txt')
# print(turnstile.shape)

# %%
# turnstile.describe()
# Out:
#             ENTRIES  \
# count  2.011180e+05
# mean   3.960628e+07
# std    2.070185e+08
# min    0.000000e+00
# 25%    4.995725e+05
# 50%    2.644323e+06
# 75%    6.905252e+06
# max    2.130144e+09
#
#        EXITS
# count                                       2.011180e+05
# mean                                        3.247217e+07
# std                                         1.909713e+08
# min                                         0.000000e+00
# 25%                                         2.533940e+05
# 50%                                         1.486711e+06
# 75%                                         4.815562e+06
# max                                         2.096928e+09

# %%
# turnstile.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2018  03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2018  07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2018  11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2018  15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  01/06/2018  19:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6470216
# 1  REGULAR  6470223
# 2  REGULAR  6470256
# 3  REGULAR  6470379
# 4  REGULAR  6470665
#
#    EXITS
# 0                                            2190123
# 1                                            2190140
# 2                                            2190229
# 3                                            2190299
# 4                                            2190366

# %%
# turnstile.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
# entrances['Entry'].head()
# Out:
# 0    YES
# 1    YES
# 2    YES
# 3    YES
# 4    YES
# Name: Entry, dtype: object

# %%
# entrances[20:]
# Out:
#      Division              Line                   Station_Name  \
# 20        BMT          Broadway                         5th Av
# 21        BMT          Broadway                         5th Av
# 22        BMT          Broadway                         5th Av
# 23        BMT          Broadway                         5th Av
# 24        BMT          Broadway                        57th St
# 25        BMT          Broadway                        57th St
# 26        BMT          Broadway                        57th St
# 27        BMT          Broadway                        57th St
# 28        BMT          Broadway                        49th St
# 29        BMT          Broadway                        49th St
# 30        BMT          Broadway                        28th St
# 31        BMT          Broadway                        28th St
# 32        BMT          Broadway                        23rd St
# 33        BMT          Broadway                        23rd St
# ...

# %%
data = pd.read_csv('https://data.ny.gov/api/views/ekwu-khcy/rows.csv?accessType=DOWNLOAD')
data.shape

# %%
df = pd.DataFrame(df)
