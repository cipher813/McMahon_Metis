# %% [markdown]
# ### Linear Regression and Learning Curve challenges
#
#
# ##### Challenge 1
#
# Generate (fake) data that is linearly related to `log(x)`.
#
# You are making this model up. It is of the form `B0 + B1*log(x) + epsilon`. (You are making up the parameters.)
#
# Simulate some data from this model.
#
# Then fit two models to it:
#
#  * quadratic (second degree polynomial)
#  * logarithmic (`log(x)`)
#
# (The second one should fit really well, since it has the same form as the underlying model!)

# %%
import math
import matplotlib.pyplot as plt
# %matplotlib inline
import random
import sklearn.cross_validation
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/brianmcmahon/anaconda3/envs/tensorflow1.4/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
random.seed(3)

x = [x/10 for x in range(100)]
beta0 = random.random()
beta1 = random.random()
y = [beta0 + beta1 * math.log(n) + random.random() for n in x]
data = pd.DataFrame({'y':y, 'x':x})
data.head()
# Out:
#      x         y
# 0  0.1 -0.645214
# 1  0.2 -0.034018
# 2  0.3  0.208448
# 3  0.4 -0.195179
# 4  0.5 -0.126098

# %%
data['constant'] = 1
data['x2'] = data['x']**2

# %%
# quadratic_fit = np.polyfit(x, y, 2)
quadratic = smf.ols(formula = 'y ~ x2', data=data).fit()
y_pred = quadratic.predict(data[['constant', 'x2']])
quadratic.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     788.7
# Date:                Tue, 30 Jan 2018   Prob (F-statistic):          2.32e-128
# Time:                        16:21:46   Log-Likelihood:                -615.85
# No. Observations:                1000   AIC:                             1236.
# Df Residuals:                     998   BIC:                             1246.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2529      0.021    105.891      0.000       2.211       2.295
# x2             0.0001   4.75e-06     28.085      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      301.924   Durbin-Watson:                   0.798
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1230.828
# Skew:                          -1.378   Prob(JB):                    5.36e-268
# Kurtosis:                       7.685   Cond. No.                     6.72e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.72e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.figure(figsize=(16,8))
plt.plot(data.x, data.y, '.', data.x, y_pred, 'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x10df974e0>,
#  <matplotlib.lines.Line2D at 0x10df97780>]

# %%
data['logx'] = data['x'].apply(math.log, 1)

# %%
logmodel = smf.ols(formula = 'y~logx', data = data).fit()
y_pred = logmodel.predict(data[['constant', 'logx']])
logmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.766
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     3272.
# Date:                Tue, 30 Jan 2018   Prob (F-statistic):          2.77e-317
# Time:                        16:21:46   Log-Likelihood:                -180.24
# No. Observations:                1000   AIC:                             364.5
# Df Residuals:                     998   BIC:                             374.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7757      0.035     22.263      0.000       0.707       0.844
# logx           0.5327      0.009     57.202      0.000       0.514       0.551
# ==============================================================================
# Omnibus:                      824.782   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               61.553
# Skew:                           0.030   Prob(JB):                     4.30e-14
# Kurtosis:                       1.786   Cond. No.                         15.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.figure(figsize=(16,8))
plt.plot(data.x, data.y, '.', data.x, y_pred, 'r-')
# Out:
# [<matplotlib.lines.Line2D at 0x10e010fd0>,
#  <matplotlib.lines.Line2D at 0x10e016160>]

# %% [markdown]
# ##### Challenge 2
#
# Generate (fake) data from a model of the form `B0 + B1*x + B2*x^2 + epsilon`. (You are making up the parameters.)
#
# Split the data into a training and test set.
#
# Fit a model to your training set. Calculate mean squared error on your training set. Then calculate it on your test set.
#
# (You could use `sklearn.metrics.mean_squared_error`.)

# %%
## Set up data frame with generated data
x = [x/10. for x in range(1, 1001, 1)]
beta0 = random.random()
beta1 = random.random()
beta2 = random.random()
y = [beta0 + beta1*n + beta2*(n**2) + (random.random()-1)*4 for n in x]
data = pd.DataFrame({'y':y, 'x':x})
data['constant'] = 1
data['x2'] = data['x']**2

# %%
x_train, x_test, y_train, y_test = sklearn.cross_validation.train_test_split(data[['constant', 'x', 'x2']], 
                                                                             data.y, train_size = 0.75)

# %%
model2 = sm.OLS(y_train, x_train).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.998e+09
# Date:                Tue, 30 Jan 2018   Prob (F-statistic):               0.00
# Time:                        16:21:46   Log-Likelihood:                -1165.4
# No. Observations:                 750   AIC:                             2337.
# Df Residuals:                     747   BIC:                             2351.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# constant      -1.0656      0.125     -8.530      0.000      -1.311      -0.820
# x              0.4092      0.006     70.666      0.000       0.398       0.421
# x2             0.8727   5.59e-05   1.56e+04      0.000       0.873       0.873
# ==============================================================================
# Omnibus:                      413.665   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.708
# Skew:                           0.027   Prob(JB):                     5.32e-10
# Kurtosis:                       1.832   Cond. No.                     1.35e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.35e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_train_pred = model2.predict(x_train)

# %%
## helper function to calculate mean square error
def mean_square_error(a, b):
    return np.mean([(a-b)**2 for a,b in zip(a,b)])

# %%
mean_square_error([0,0], [2,4])
# Out:
# 10.0

# %%
mean_square_error(y_train_pred, y_train)
# Out:
# 1.3096335109769957

# %%
## Perform model on test set
y_test_predict = model2.predict(x_test)
mean_square_error(y_test_predict, y_test)
# Out:
# 1.315224298054672

# %% [markdown]
# ##### Challenge 3
#
# For the data from two (above), try polynomial fits from 0th (just constant) to 7th order (highest term x^7). Over the x axis of model degree (8 points), plot:
#
#  * training error
#  * test error
#  * R squared
#  * AIC

# %%
data = pd.DataFrame({'y':y, 'x':x})

# %%
def polynomial_fit(df, order):
    columns = []
    
    for n in range(order+1):
        col = 'x'+str(n)
        columns.append(col)
        df[col] = df['x']**n
        
    x = df[columns]
    y = df.y
    
    x_train, x_test, y_train, y_test = sklearn.cross_validation.train_test_split(x, y, train_size = 0.75)
    
    model = sm.OLS(y_train, x_train).fit()

    y_train_hat = model.predict(x_train)
    training_error = mean_square_error(y_train, y_train_hat)
    print(model.mse_resid)
    y_test_hat = model.predict(x_test)
    testing_error = mean_square_error(y_test, y_test_hat)
    
    return [training_error, testing_error, model.rsquared, model.aic]

# %%
orders = range(7)
results = [polynomial_fit(data, n) for n in orders]
# Out:
# 6799510.055351675
# 422639.211705364
# 1.3406233116000523
# 1.3485069046299378
# 1.3268849516723882
# 1.3153609477574486
# 1.3464930813176887

# %%
train_error = [n[0] for n in results]
test_error = [n[1] for n in results]
r2 = [n[2] for n in results]
aic = [n[3] for n in results]

# %%
plt.figure(figsize=(10,6))
plt.plot(orders, train_error, 'r--', label = 'Training Error', )
plt.plot(orders, test_error, '--', label = 'Testing Error')
plt.legend()

# %%
plt.figure(figsize=(10,6))
plt.plot(orders, r2, 'r-' )
plt.title('R-squared vs polynomial orders')
plt.xlabel('Polynomial order')
plt.ylabel('R-Squared value')
# Out:
# Text(0,0.5,'R-Squared value')

# %%
plt.figure(figsize=(10,6))
plt.plot(orders, aic, 'b-' )
plt.title('Akaike information criterion (AIC) vs polynomial orders')
plt.xlabel('Polynomial order')
plt.ylabel('Akaike information criterion (AIC)')
# Out:
# Text(0,0.5,'Akaike information criterion (AIC)')

# %% [markdown]
# ##### Challenge 4
#
# For the data from two (above), fit a model to only the first 5 of your data points (m=5). Then to first 10 (m=10). Then to first 15 (m=15). In this manner, keep fitting until you fit your entire training set. For each step, calculate the training error and the test error. Plot both (in the same plot) over m. This is called a learning curve.

# %%
## Function that models a quadratic regression line and return the training and test error

def regression_error(df, m):
    ## slices the dataframe
    df = df[:m]
        
    x = df.drop(['y'],1)
    y = df.y
    
    x_train, x_test, y_train, y_test = sklearn.cross_validation.train_test_split(x, y, train_size = 0.75)
    
    model = sm.OLS(y_train, x_train).fit()

    y_train_hat = model.predict(x_train)
    training_error = mean_square_error(y_train, y_train_hat)
#     print model.mse_resid
    y_test_hat = model.predict(x_test)
    testing_error = mean_square_error(y_test, y_test_hat)
    
    return [training_error, testing_error]

# %%
## Build a list of data points from 5 to 100.
m = range(5,101, 5)
results4 = [regression_error(data, k) for k in m]

# %%
train_error = [a[0] for a in results4]
test_error = [a[1] for a in results4]

# %%
plt.figure(figsize=(16,8))
plt.plot(m, train_error, 'r--', label = 'Training Error')
plt.plot(m, test_error, 'g--', label = "Test Error")
plt.legend()
plt.xlabel('Data points (m)')
plt.ylabel('Error (MSE)')
print('Training and Testing Error vs. Data points (m) built on model')
# Out:
# Training and Testing Error vs. Data points (m) built on model
